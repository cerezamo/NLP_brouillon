# %%
from bs4 import BeautifulSoup as bs
from bs4 import SoupStrainer
from selenium import webdriver
import time, re
import requests
from itertools import repeat
import pandas as pd
import numpy as np
import unicodedata2
from tqdm import tqdm

# %%
link_list = []
unique_id = []
speech_type = []

# %%
# Faudrait faire une liste et startwith tuple(list) mais après comment j'append ? 
types_de_speech = ['Déclaration','Interview','Allocution','Conférence de presse',"Extraits d'un entretien",'Entretien','Message']
for i in tqdm(range(51,800)):
    link = 'https://www.vie-publique.fr/discours' +'?page='+ str(i)
    page_resp=requests.get(link)
    content= bs(page_resp.content,'html.parser',parse_only=SoupStrainer('main'))
    for link in content.find_all("a", class_='link-multiple'):
        if link.find('span').text.startswith(tuple(types_de_speech)):
            link_list.append('https://www.vie-publique.fr'+ link.get('href'))
            unique_id.append(link.get('href').split('/')[2].split('-')[0])
            speech_type.append(link.find('span').text.split(' ')[0])
# Out:
# 100%|██████████| 749/749 [09:41<00:00,  1.29it/s]

# %% [markdown]
# Essai sur les premières pages

# %%
LINKS=pd.DataFrame({'unique_id':unique_id,'speech_type':speech_type,'link':link_list})
LINKS=LINKS.drop_duplicates(subset=['unique_id'],ignore_index=True)
LINKS.head()
# Out:
#   unique_id   speech_type                                               link
# 0    272458   Déclaration  https://www.vie-publique.fr/discours/272458-br...
# 1    272635   Déclaration  https://www.vie-publique.fr/discours/272635-je...
# 2    272488  Déclarations  https://www.vie-publique.fr/discours/272488-br...
# 3    272186      Extraits  https://www.vie-publique.fr/discours/272186-en...
# 4    272235     Interview  https://www.vie-publique.fr/discours/272235-je...

# %%
LINKS
# Out:
#      unique_id   speech_type  \
# 0       272458   Déclaration
# 1       272635   Déclaration
# 2       272488  Déclarations
# 3       272186      Extraits
# 4       272235     Interview
# ...        ...           ...
# 7294    200488   Déclaration
# 7295    200416   Déclaration
# 7296    200320   Déclaration
# 7297    200407   Déclaration
# 7298    200506   Déclaration
#
#                                                    link
# 0     https://www.vie-publique.fr/discours/272458-br...
# 1     https://www.vie-publique.fr/discours/272635-je...
# 2     https://www.vie-publique.fr/discours/272488-br...
# 3     https://www.vie-publique.fr/discours/272186-en...
# 4     https://www.vie-publique.fr/discours/272235-je...
# ...                                                 ...
# 7294  https://www.vie-publique.fr/discours/200488-de...
# 7295  https://www.vie-publique.fr/discours/200416-de...
# 7296  https://www.vie-publique.fr/discours/200320-de...
# 7297  https://www.vie-publique.fr/discours/200407-de...
# 7298  https://www.vie-publique.fr/discours/200506-de...
#
# [7299 rows x 3 columns]

# %%
length = '0-800-2902020'
LINKS.to_csv('DATA_' +length+'.csv')

# %% [markdown]
# Quelles infos extra prendre ?
# - Intervenant (PB quand plusieurs si non journaliste ? )
# - Fonction (OK mais possibles erreurs à checker ! )
# - Titre
# - date # mettre as date
# - sujet principal (about) # pas encore fait
# - Thématique
# - publications dans d'autres médias ? # pas encore fait
# - Interview : mettre radio ou journal considéré
# - discours ( à checker)
#
# Ex : pb avec https://www.vie-publique.fr/discours/272865-ministere-de-leurope-et-des-affaires-etrangeres-20012020-ormuz

# %%
chrome_options = webdriver.ChromeOptions()
#chrome_options.add_argument('--headless')
#chrome_options.add_argument('--no-sandbox') 
chrome_options.add_argument('--disable-notifications')
chrome_options.add_argument("--disable-extensions")

# %% [markdown]
# # Selenium

# %% [raw]
# prenom=[]
# nom=[]
# titre=[]
# date=[]
# theme=[]
# mots_cle=[]
# discours=[]
# merge_id=[]
# fonct=[]
# inter_fonct=[]

# %%
# Premier code d'extraction, deuxième code après le premier round pour ceux qui ont pas marché. 
#print('DATA_' +length)
from selenium.common.exceptions import NoSuchElementException
prenom=[]
nom=[]
titre=[]
date=[]
theme=[]
mots_cle=[]
discours=[]
merge_id=[]
fonct=[]
inter_fonct=[]

d = webdriver.Chrome(options=chrome_options)

for j in tqdm(range(len(LINKS.link))):
    try:
        d.get(LINKS.link[j])
    except:
        pass
    
    merge_id.append(LINKS.unique_id[j])
    try:
        titre.append(d.find_element_by_xpath("//h1[contains(@class, 'h')]").text)
    except:
        titre.append(np.nan)
    try:
        fonct.append(d.find_element_by_class_name("line-intervenant").text.replace('\n',' ').split(' - ')[1])  
    except:
        fonct.append(np.nan)       
    try:
        theme.append(d.find_element_by_class_name('thematicBox').text.replace('Thématique(s) :\n',''))
    except:
        theme.append(np.nan)
    try:
        prenom.append(d.find_element_by_class_name("line-intervenant").text.split(' - ')[0].split(' ')[0])
    except: 
        prenom.append(np.nan)
    try:
        nom.append(' '.join(d.find_element_by_class_name("line-intervenant").text.split('\n')[0].split(' - ')[0].split(' ')[1:]))
    except:
        nom.append(np.nan)
    try:
        date.append(d.find_element_by_tag_name('time').get_attribute(("datetime"))) # set as date 
    except:
        date.append(np.nan)
    try:
        mots_cle.append(d.find_element_by_class_name('tagsBox').text.replace('MOTS-CLÉS :\n','').replace('\n',' '))
    except:
        mots_cle.append('PAS DE MOTS CLE')
    try: 
        para=d.find_element_by_xpath("//span[contains(@class, 'texte-integral')]").find_element_by_xpath("//span[contains(@class, 'texte-integral')]").text.split('\n')
        para = [x for x in para if x != '']
        discours_s= []
        # A rassembler les if en un seul quand même code avec liste et isin 
        if LINKS.speech_type[j]=='Déclaration': 
            for a in para:
                if not a.startswith('Source'):  
                    discours_s.append(a)
                    #merge_id_s.append(unique_id[j])
                    
        if LINKS.speech_type[j]=='Allocution':
            for a in para:
                if not a.startswith('Source'):  # remplacer par html mais prend temps
                    discours_s.append(a)
                    #merge_id_s.append(unique_id[j])
                    
        if LINKS.speech_type[j]=='Message':
            for a in para:
                if not a.startswith('Source'):  # remplacer par html mais prend temps
                    discours_s.append(a)
                    #merge_id_s.append(unique_id[j])
                    
        if LINKS.speech_type[j]=='Interview':
            for i in range(len(para)-1):
                nomprenom=d.find_element_by_class_name("line-intervenant").text.split(' - ')[0].upper()
                if para[i].startswith(nomprenom):
                    if not para[i].replace(nomprenom,'')==' ':
                        discours_s.append(para[i].replace(nomprenom,''))
                    if not para[i+1].replace(nomprenom,'')==' ':
                        discours_s.append(para[i+1].replace(nomprenom,''))
            if len(discours_s)==0:
                for i in range(len(para)-1):
                    if para[i].startswith('R -'):
                        discours_s.append(para[i].replace('R -',''))
            if len(discours_s)==0:
                prenom_nom=d.find_element_by_class_name("line-intervenant").text.split(' - ')[0].split(' ')[0] + ' '+ ' '.join(d.find_element_by_class_name("line-intervenant").text.split('\n')[0].split(' - ')[0].split(' ')[1:]) +' :'
                for i in range(len(para)-1):
                    if para[i].startswith(prenom_nom):
                        discours_s.append(para[i].strip(prenom_nom))
            if len(discours_s)==0:
                if para[0].startswith('?'):
                    for i in range(len(para)-1):
                        if not para[i].startswith('?'):
                            discours_s.append(para[i])
                        
        if LINKS.speech_type[j]=='Entretien':
            for i in range(len(para)-1):
                if para[i].startswith(d.find_element_by_class_name("line-intervenant").text.split(' - ')[0].upper()):
                    discours_s.append(para[i+1])
            if len(discours_s)==0:
                for i in range(len(para)-1):
                    if para[i].startswith('R -'):
                        discours_s.append(para[i].replace('R -','')) # Parfois relou ca prend deux paragraphes... faut voir pour stopper quand Q - + je peux pas faire if not
# Un exemple : https://www.vie-publique.fr/discours/185845-entretien-de-m-laurent-fabius-ministre-des-affaires-etrangeres-avec-l

        if LINKS.speech_type[j]=='Extraits':
            for i in range(len(para)-1):
                if para[i].startswith(d.find_element_by_class_name("line-intervenant").text.split(' - ')[0].upper()):
                    discours_s.append(para[i+1])
            if len(discours_s)==0:
                for i in range(len(para)-1):
                    if para[i].startswith('R -'):
                        discours_s.append(para[i].replace('R -',''))
                        
        if LINKS.speech_type[j]=='Conférence':
            for i in range(len(para)-1):
                if para[i].startswith(d.find_element_by_class_name("line-intervenant").text.split(' - ')[0].upper()):
                    discours_s.append(para[i+1])
            if len(discours_s)==0:
                for i in range(len(para)-1):
                    if para[i].startswith('R -'):
                        discours_s.append(para[i].replace('R -',''))
        discours.append(' '.join(discours_s))
    except:
        discours.append(np.nan)
    #time.sleep(1)
    #print(j)
d.close()
print(j)

# NB : Peut être essayer de récupérer le texte même si erreur ? ( on en a assez en vrai)
# J'étais obligée les try except pour chaque truc ca bug à chaque fois sinon ... Autre méthode ? 
                                      
# Plus je pense que la ca fonctionne jusquà la page 1000, j'ai un soucis de nom aussi
# Out:
# 100%|██████████| 7299/7299 [17:15:52<00:00,  8.52s/it]
# 7298

# %% [markdown]
# # Beautiful SOup

# %% [raw]
# # Premier code d'extraction, deuxième code après le premier round pour ceux qui ont pas marché.
# #print('DATA_' +length)
# from selenium.common.exceptions import NoSuchElementException
# prenom=[]
# nom=[]
# titre=[]
# date=[]
# theme=[]
# mots_cle=[]
# discours=[]
# merge_id=[]
# fonct=[]
# inter_fonct=[]
#
# for j in tqdm(range(len(LINKS.link))):
#     try:
#         page_resp=requests.get(LINKS.link[j])
#     except:
#         pass
#     bs_obj = bs(page_resp.content,'html.parser')
#     merge_id.append(LINKS.unique_id[j])
#     try:
#         titre.append(bs_obj.find('h1').text.replace('\n',''))
#     except:
#         titre.append(np.nan)
#     try:
#         fonct.append(bs_obj.find_all('ul', {'class': 'line-intervenant'})[0].find('li').text.replace('\n','').split(' - ')[1:])
#     except:
#         fonct.append(np.nan)
#     try:
#         theme.append(bs_obj.find('div', {'class': 'thematicBox'}).text.replace('\n','').replace('Thématique(s) : ',''))
#     except:
#         theme.append(np.nan)
#     try:
#         prenom.append(bs_obj.find_all('ul', {'class': 'line-intervenant'})[0].find('li').text.replace('\n','').split(' - ')[0].split(' ')[0])
#     except:
#         prenom.append(np.nan)
#     try:
#         nom.append(' '.join(bs_obj.find_all('ul', {'class': 'line-intervenant'})[0].find('li').text.replace('\n','').split(' - ')[0].strip(' ').split(' ')[1:]))
#     except:
#         nom.append(np.nan)
#     try:
#         date.append(bs_obj.find('time').get('datetime')) # set as date
#     except:
#         date.append(np.nan)
#     try:
#         mots_cle.append(bs_obj.find('div', {'class': 'tagsBox'}).text.replace('mots-clés : ','').replace('\n',' ').replace('  ','').strip(' ').replace(' - ','-').split(' '))
#     except:
#         mots_cle.append('PAS DE MOTS CLE')
#     try:
#         para=bs_obj.find('span', class_=lambda c: 'texte-integral' in c).text.split('\n')
#         para = [x for x in para if x != '']
#         discours_s= []
#         # A rassembler les if en un seul quand même code avec liste et isin
#         if LINKS.speech_type[j]=='Déclaration':
#             for a in para:
#                 if not a.startswith('Source'):
#                     discours_s.append(a)
#                     #merge_id_s.append(unique_id[j])
#
#         if LINKS.speech_type[j]=='Allocution':
#             for a in para:
#                 if not a.startswith('Source'):  # remplacer par html mais prend temps
#                     discours_s.append(a)
#                     #merge_id_s.append(unique_id[j])
#
#         if LINKS.speech_type[j]=='Message':
#             for a in para:
#                 if not a.startswith('Source'):  # remplacer par html mais prend temps
#                     discours_s.append(a)
#                     #merge_id_s.append(unique_id[j])
#
#         if LINKS.speech_type[j]=='Interview':
#             for i in range(len(para)-1):
#                 if para[i].startswith(bs_obj.find_all('ul', {'class': 'line-intervenant'})[0].find('li').text.replace('\n','').split(' - ')[0].strip(' ').upper()):
#                     if not para[i].replace(bs_obj.find_all('ul', {'class': 'line-intervenant'})[0].find('li').text.replace('\n','').split(' - ')[0].strip(' ').upper(),'')==' ':
#                         discours_s.append(para[i].replace(bs_obj.find_all('ul', {'class': 'line-intervenant'})[0].find('li').text.replace('\n','').split(' - ')[0].strip(' ').upper(),''))
#                     if not para[i+1].replace(bs_obj.find_all('ul', {'class': 'line-intervenant'})[0].find('li').text.replace('\n','').split(' - ')[0].strip(' ').upper(),'')==' ':
#                         discours_s.append(para[i+1].replace(bs_obj.find_all('ul', {'class': 'line-intervenant'})[0].find('li').text.replace('\n','').split(' - ')[0].strip(' ').upper(),''))
#             if len(discours_s)==0:
#                 for i in range(len(para)-1):
#                     if para[i].startswith('R -'):
#                         discours_s.append(para[i].replace('R -',''))
#             if len(discours_s)==0:
#                 prenom_nom=bs_obj.find_all('ul', {'class': 'line-intervenant'})[0].find('li').text.replace('\n','').split(' - ')[0].strip(' ') + ' '+ ' '.join(d.find_element_by_class_name("line-intervenant").text.split('\n')[0].split(' - ')[0].split(' ')[1:]) +' :'
#                 for i in range(len(para)-1):
#                     if para[i].startswith(prenom_nom):
#                         discours_s.append(para[i].strip(prenom_nom))
#             if len(discours_s)==0:
#                 if para[0].startswith('?'):
#                     for i in range(len(para)-1):
#                         if not para[i].startswith('?'):
#                             discours_s.append(para[i])
#
#         if LINKS.speech_type[j]=='Entretien':
#             for i in range(len(para)-1):
#                 if para[i].startswith(bs_obj.find_all('ul', {'class': 'line-intervenant'})[0].find('li').text.replace('\n','').split(' - ')[0].strip(' ').upper()):
#                     discours_s.append(para[i+1])
#             if len(discours_s)==0:
#                 for i in range(len(para)-1):
#                     if para[i].startswith('R -'):
#                         discours_s.append(para[i].replace('R -','')) # Parfois relou ca prend deux paragraphes... faut voir pour stopper quand Q - + je peux pas faire if not
# # Un exemple : https://www.vie-publique.fr/discours/185845-entretien-de-m-laurent-fabius-ministre-des-affaires-etrangeres-avec-l
#
#         if LINKS.speech_type[j]=='Extraits':
#             for i in range(len(para)-1):
#                 if para[i].startswith(bs_obj.find_all('ul', {'class': 'line-intervenant'})[0].find('li').text.replace('\n','').split(' - ')[0].strip(' ').upper()):
#                     discours_s.append(para[i+1])
#             if len(discours_s)==0:
#                 for i in range(len(para)-1):
#                     if para[i].startswith('R -'):
#                         discours_s.append(para[i].replace('R -',''))
#
#         if LINKS.speech_type[j]=='Conférence':
#             for i in range(len(para)-1):
#                 if para[i].startswith(bs_obj.find_all('ul', {'class': 'line-intervenant'})[0].find('li').text.replace('\n','').split(' - ')[0].strip(' ').upper()):
#                     discours_s.append(para[i+1])
#             if len(discours_s)==0:
#                 for i in range(len(para)-1):
#                     if para[i].startswith('R -'):
#                         discours_s.append(para[i].replace('R -',''))
#         discours.append(' '.join(discours_s))
#     except:
#         discours.append(np.nan)
#     #time.sleep(1)
#     #print(j)
# print(j)
#
# # NB : Peut être essayer de récupérer le texte même si erreur ? ( on en a assez en vrai)
# # J'étais obligée les try except pour chaque truc ca bug à chaque fois sinon ... Autre méthode ?
#
# # Plus je pense que la ca fonctionne jusquà la page 1000, j'ai un soucis de nom aussi
#
# # Je change en beautiful soup pour le parser ca va plus vite mais j'y arrive pas il y a du texte dynamique relou faut que je prenne tout dans le titre
# # .En collab j'essaye de parraléliser pour augmenter encore un peu.
# #15 minutes les 2000 textes environ, ca passe.

# %%
DATA =pd.DataFrame({'titre':titre,
                    'link':LINKS.link,
                    'speech_type' :LINKS.speech_type,
                    'prenom':prenom,
                    'nom' : nom,
                    'date':date,
                   'theme':theme,
                   'fonct':fonct,
                   'unique_id':LINKS.unique_id}
                  )
DISCOURS = pd.DataFrame({'merge_id':merge_id,
                         'discours':discours})

# %%
DATA.to_csv('DATA.csv')
DISCOURS.to_csv('DISCOURS.csv')

# %%
DATA=pd.read_csv('DATA.csv')
DISCOURS=pd.read_csv('DISCOURS.csv')

# %%
for i in range(len(mots_cle)):
    if mots_cle[i] is np.nan:
        mots_cle[i]=''
    else:
        mots_cle[i]=mots_cle[i].replace(' - ','-')
        mots_cle[i]=mots_cle[i].replace("INSTITUTIONS DE L'ETAT","INSTITUTIONS-DE-L'ETAT")
        mots_cle[i]=mots_cle[i].replace(' EUROP','-EUROP')
        mots_cle[i]=mots_cle[i].replace('VIE EC','VIE-EC')
        mots_cle[i]=mots_cle[i].replace('ITIQUE ','ITIQUE-')
        mots_cle[i]=mots_cle[i].replace('ZONE ','ZONE-')
        mots_cle[i]=mots_cle[i].replace('RELATIONS ','RELATIONS-')
        mots_cle[i]=mots_cle[i].split(' ') 
# Faire une sorte de regroupement de mots cle avec l'algo vu en cours ?
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-81-6251bd2391b0> in <module>
#       3         mots_cle[i]=''
#       4     else:
# ----> 5         mots_cle[i]=mots_cle[i].replace(' - ','-')
#       6         mots_cle[i]=mots_cle[i].replace("INSTITUTIONS DE L'ETAT","INSTITUTIONS-DE-L'ETAT")
#       7         mots_cle[i]=mots_cle[i].replace(' EUROP','-EUROP')
#
# AttributeError: 'list' object has no attribute 'replace'

# %%
col= []
for i in range(len(max([x for x in mots_cle if x is not np.nan], key=len))):
    col.append('MC'+str(i+1))
col
# Out:
# ['MC1', 'MC2', 'MC3', 'MC4', 'MC5', 'MC6', 'MC7', 'MC8', 'MC9', 'MC10']

# %%
MOTS_CLE=pd.DataFrame(data=mots_cle,columns=col)
MOTS_CLE.to_csv('MOTS_CLE.csv')

# %%
DATA=pd.concat([DATA,MOTS_CLE],axis=1)
DATA=DATA.merge(DISCOURS, left_on='unique_id',right_on='merge_id')
DATA.columns
DATA.head()
# Out:
#    Unnamed: 0_x                                              titre  \
# 0             0  Déclaration de Mme Brune Poirson, secrétaire d...
# 1             1  Déclaration de M. Jean-Michel Blanquer, minist...
# 2             2  Déclarations de M. Bruno Le Maire, ministre de...
# 3             3  Extraits d'un entretien de M. Jean-Baptiste Le...
# 4             4  Interview de M. Jean-Michel Blanquer, ministre...
#
#                                                 link   speech_type  \
# 0  https://www.vie-publique.fr/discours/272458-br...   Déclaration
# 1  https://www.vie-publique.fr/discours/272635-je...   Déclaration
# 2  https://www.vie-publique.fr/discours/272488-br...  Déclarations
# 3  https://www.vie-publique.fr/discours/272186-en...      Extraits
# 4  https://www.vie-publique.fr/discours/272235-je...     Interview
#
#           prenom       nom                  date          theme  \
# 0          Brune   Poirson  2019-12-03T12:00:00Z        SOCIÉTÉ
# 1    Jean-Michel  Blanquer  2019-12-03T12:00:00Z        SOCIÉTÉ
# 2          Bruno  Le Maire  2019-12-03T12:00:00Z        SOCIÉTÉ
# 3  Jean-Baptiste   Lemoyne  2019-12-02T12:00:00Z  INTERNATIONAL
# 4    Jean-Michel  Blanquer  2019-12-02T12:00:00Z        SOCIÉTÉ
#
#                                                fonct  unique_id  ...   MC4  \
# 0  Secrétaire d'Etat auprès du ministre de la tra...     272458  ...  None
# 1  Ministre de l'éducation nationale et de la jeu...     272635  ...  None
# 2  Ministre de l'économie et des finances Marlène...     272488  ...  None
# 3  Secrétaire d'État auprès du ministre de l'Euro...     272186  ...  None
# 4  Ministre de l'éducation nationale et de la jeu...     272235  ...  None
#
#     MC5   MC6   MC7   MC8   MC9  MC10 Unnamed: 0_y merge_id  \
# 0  None  None  None  None  None  None            0   272458
# 1  None  None  None  None  None  None            1   272635
# 2  None  None  None  None  None  None            2   272488
# 3  None  None  None  None  None  None            3   272186
# 4  None  None  None  None  None  None            4   272235
#
#                                             discours
# 0  Monsieur le Député, Vous avez raison de pointe...
# 1  Mesdames et messieurs les Professeurs,  Le Gou...
# 2                                                NaN
# 3   Je souhaite toute mon émotion et toute l'émot...
# 4   Bonjour Alba VENTURA.  C'est toujours importa...
#
# [5 rows x 23 columns]

# %%
col=[col for col in DATA if col.startswith('MC')]

# %%
for C in col : 
    DATA[C]=DATA[C].replace(to_replace=[None], value=' ')

# %%
DATA=DATA[~DATA.prenom.isna()]

# %%
len(DATA)
# Out:
# 7226

# %%
#DATA=DATA[~DATA.fonct.isna()]

# %%
# Pour les discours plus vieux, la fonction se trouve uniquement dans le titre 
#DATA['fonct'] = DATA.apply(
#    lambda row: row['titre'].split(',')[1] if np.isnan(row['fonct']) else row['fonct'],
#    axis=1

#)

# %%
len(DATA)
# Out:
# 5737

# %%
DATA.dropna(subset=['discours'],inplace=True)

# %%
DATA=DATA[DATA.discours != '']
DATA.reset_index(inplace=True)
del DATA['index']
del DATA['level_0']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'level_0'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-99-0dd0ddac9eb6> in <module>
#       2 DATA.reset_index(inplace=True)
#       3 del DATA['index']
# ----> 4 del DATA['level_0']
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __delitem__(self, key)
#    3757             # there was no match, this call should raise the appropriate
#    3758             # exception:
# -> 3759             self._data.delete(key)
#    3760
#    3761         # delete from the caches
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in delete(self, item)
#    1000         Delete selected item (items if non-unique) in-place.
#    1001         """
# -> 1002         indexer = self.items.get_loc(item)
#    1003
#    1004         is_deleted = np.zeros(self.shape[0], dtype=np.bool_)
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'level_0'

# %%
DATA.to_csv('Sample_51_800.csv')

# %%
len(DATA)
# Out:
# 5737

# %%
#Faut voir avec le merge id si ca colle ...

# %% [markdown]
# ### Merge label prénoms

# %%
pd.read_csv('Sample_51_800.csv')
# Out:
#       Unnamed: 0  Unnamed: 0_x  \
# 0              0             0
# 1              1             1
# 2              2             3
# 3              3             4
# 4              4             5
# ...          ...           ...
# 5732        5732          7294
# 5733        5733          7295
# 5734        5734          7296
# 5735        5735          7297
# 5736        5736          7298
#
#                                                   titre  \
# 0     Déclaration de Mme Brune Poirson, secrétaire d...
# 1     Déclaration de M. Jean-Michel Blanquer, minist...
# 2     Extraits d'un entretien de M. Jean-Baptiste Le...
# 3     Interview de M. Jean-Michel Blanquer, ministre...
# 4     Déclaration de M. Emmanuel Macron, président d...
# ...                                                 ...
# 5732  Déclaration de M. Harlem Désir, secrétaire d'E...
# 5733  Déclaration de M. Jean-Marc Todeschini, secrét...
# 5734  Déclaration de M. Manuel Valls, Premier minist...
# 5735  Déclaration de M. Jean-Marc Todeschini, secrét...
# 5736  Déclaration de Mme Najat Vallaud-Belkacem, min...
#
#                                                    link  speech_type  \
# 0     https://www.vie-publique.fr/discours/272458-br...  Déclaration
# 1     https://www.vie-publique.fr/discours/272635-je...  Déclaration
# 2     https://www.vie-publique.fr/discours/272186-en...     Extraits
# 3     https://www.vie-publique.fr/discours/272235-je...    Interview
# 4     https://www.vie-publique.fr/discours/272165-em...  Déclaration
# ...                                                 ...          ...
# 5732  https://www.vie-publique.fr/discours/200488-de...  Déclaration
# 5733  https://www.vie-publique.fr/discours/200416-de...  Déclaration
# 5734  https://www.vie-publique.fr/discours/200320-de...  Déclaration
# 5735  https://www.vie-publique.fr/discours/200407-de...  Déclaration
# 5736  https://www.vie-publique.fr/discours/200506-de...  Déclaration
#
#              prenom               nom                  date          theme  \
# 0             Brune           Poirson  2019-12-03T12:00:00Z        SOCIÉTÉ
# 1       Jean-Michel          Blanquer  2019-12-03T12:00:00Z        SOCIÉTÉ
# 2     Jean-Baptiste           Lemoyne  2019-12-02T12:00:00Z  INTERNATIONAL
# 3       Jean-Michel          Blanquer  2019-12-02T12:00:00Z        SOCIÉTÉ
# 4          Emmanuel            Macron  2019-12-02T12:00:00Z  INTERNATIONAL
# ...             ...               ...                   ...            ...
# 5732         Harlem             Désir  2016-09-01T12:00:00Z  INTERNATIONAL
# 5733      Jean-Marc        Todeschini  2016-09-01T12:00:00Z        SOCIÉTÉ
# 5734         Manuel             Valls  2016-09-01T12:00:00Z  INTERNATIONAL
# 5735      Jean-Marc        Todeschini  2016-09-01T12:00:00Z  INTERNATIONAL
# 5736          Najat  Vallaud-Belkacem  2016-08-31T12:00:00Z        SOCIÉTÉ
#
#                                                   fonct  ...  MC4 MC5 MC6 MC7  \
# 0     Secrétaire d'Etat auprès du ministre de la tra...  ...
# 1     Ministre de l'éducation nationale et de la jeu...  ...
# 2     Secrétaire d'État auprès du ministre de l'Euro...  ...
# 3     Ministre de l'éducation nationale et de la jeu...  ...
# 4                            Président de la République  ...
# ...                                                 ...  ...  ...  ..  ..  ..
# 5732                                                NaN  ...
# 5733                                                NaN  ...
# 5734                                                NaN  ...
# 5735                                                NaN  ...
# 5736                                                NaN  ...
#
#      MC8 MC9 MC10 Unnamed: 0_y merge_id  \
# 0                            0   272458
# 1                            1   272635
# 2                            3   272186
# 3                            4   272235
# 4                            5   272165
# ...   ..  ..  ...          ...      ...
# 5732                      7294   200488
# 5733                      7295   200416
# 5734                      7296   200320
# 5735                      7297   200407
# 5736                      7298   200506
#
#                                                discours
# 0     Monsieur le Député, Vous avez raison de pointe...
# 1     Mesdames et messieurs les Professeurs,  Le Gou...
# 2      Je souhaite toute mon émotion et toute l'émot...
# 3      Bonjour Alba VENTURA.  C'est toujours importa...
# 4     Officiers, sous-officiers, soldats, marins, av...
# ...                                                 ...
# 5732  Madame la Présidente de la Commission des affa...
# 5733  Monsieur le Préfet, Monsieur le Député-Préside...
# 5734  Messieurs les ministres, Mesdames, messieurs l...
# 5735  Monsieur le Préfet, Mesdames et messieurs les ...
# 5736  Je suis heureuse d'intervenir dans le cadre de...
#
# [5737 rows x 24 columns]

# %%
# On peut aussi aller chercher le madame monsieur ! 
prenoms=pd.read_csv(r'C:\Users\morga\Documents\GitHub\NLP_brouillon\nat2018.csv',sep=';')
prenoms=prenoms.groupby(['preusuel','sexe'],as_index=False).sum()
prenoms=prenoms.sort_values(['nombre'],ascending=True)
prenoms=prenoms.drop_duplicates(subset=['preusuel'],keep='last') # On prend le sexe qui apparait le plus 
prenoms=prenoms[['preusuel','sexe']]
DATA.prenom=[pre.upper() for pre in DATA.prenom.astype('string')]
DATA=DATA.merge(prenoms, left_on='prenom',right_on='preusuel')

# %%
DATA.to_csv('Sample_51_800.csv')

# %% [markdown]
# ### Themes

# %%
DATA=pd.read_csv('Sample_0_200.csv')

# %%
DATA=DATA.drop(columns='preusuel')

# %%
theme_clean=[]
for theme in DATA.theme:
    if len(theme.split('\n'))==0:
        theme_clean.append(theme)
    if len(theme.split('\n'))>0:
        theme_clean.append(theme.split('\n')[0])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-106-1320720ae1db> in <module>
#       1 theme_clean=[]
#       2 for theme in DATA.theme:
# ----> 3     if len(theme.split('\n'))==0:
#       4         theme_clean.append(theme)
#       5     if len(theme.split('\n'))>0:
#
# AttributeError: 'float' object has no attribute 'split'

# %%
DATA.theme=theme_clean

# %%
DATA
# Out:
#       Unnamed: 0  Unnamed: 0_x  \
# 0              0             0
# 1              1            17
# 2              2            38
# 3              3           269
# 4              4           449
# ...          ...           ...
# 5581        5581          7263
# 5582        5582          7269
# 5583        5583          7296
# 5584        5584          6846
# 5585        5585          6878
#
#                                                   titre  \
# 0     Déclaration de Mme Brune Poirson, secrétaire d...
# 1     Interview de Mme Brune Poirson, secrétaire d'É...
# 2     Interview de Mme Brune Poirson, secrétaire d'É...
# 3     Déclaration de Mme Brune Poirson, secrétaire d...
# 4     Déclaration de de Mme Brune Poirson, secrétair...
# ...                                                 ...
# 5581  Interview de M. Manuel Valls, Premier ministre...
# 5582  Déclaration de M. Manuel Valls, Premier minist...
# 5583  Déclaration de M. Manuel Valls, Premier minist...
# 5584  Déclaration de Mme Hélène Geoffroy, secrétaire...
# 5585  Déclaration de Mme Hélène Geoffroy, secrétaire...
#
#                                                    link  speech_type  prenom  \
# 0     https://www.vie-publique.fr/discours/272458-br...  Déclaration   BRUNE
# 1     https://www.vie-publique.fr/discours/272457-br...    Interview   BRUNE
# 2     https://www.vie-publique.fr/discours/272456-br...    Interview   BRUNE
# 3     https://www.vie-publique.fr/discours/272455-br...  Déclaration   BRUNE
# 4     https://www.vie-publique.fr/discours/271265-br...  Déclaration   BRUNE
# ...                                                 ...          ...     ...
# 5581  https://www.vie-publique.fr/discours/200319-in...    Interview  MANUEL
# 5582  https://www.vie-publique.fr/discours/200358-de...  Déclaration  MANUEL
# 5583  https://www.vie-publique.fr/discours/200320-de...  Déclaration  MANUEL
# 5584  https://www.vie-publique.fr/discours/200893-de...  Déclaration  HÉLÈNE
# 5585  https://www.vie-publique.fr/discours/200827-de...  Déclaration  HÉLÈNE
#
#            nom                  date          theme  \
# 0      Poirson  2019-12-03T12:00:00Z        SOCIÉTÉ
# 1      Poirson  2019-11-28T12:00:00Z        SOCIÉTÉ
# 2      Poirson  2019-11-26T12:00:00Z        SOCIÉTÉ
# 3      Poirson  2019-10-25T12:00:00Z        SOCIÉTÉ
# 4      Poirson  2019-10-03T12:00:00Z        SOCIÉTÉ
# ...        ...                   ...            ...
# 5581     Valls  2016-09-06T12:00:00Z   INSTITUTIONS
# 5582     Valls  2016-09-06T12:00:00Z  INTERNATIONAL
# 5583     Valls  2016-09-01T12:00:00Z  INTERNATIONAL
# 5584  Geoffroy  2016-10-19T12:00:00Z        SOCIÉTÉ
# 5585  Geoffroy  2016-10-17T12:00:00Z        SOCIÉTÉ
#
#                                                   fonct  ...  MC5 MC6 MC7 MC8  \
# 0     Secrétaire d'Etat auprès du ministre de la tra...  ...
# 1     Secrétaire d'État auprès de la ministre de la ...  ...
# 2     Secrétaire d'État auprès de la ministre de la ...  ...
# 3     Secrétaire d'État auprès du ministre de la tra...  ...
# 4     , Secrétaire d'État auprès de la ministre de l...  ...
# ...                                                 ...  ...  ...  ..  ..  ..
# 5581                                                NaN  ...
# 5582                                                NaN  ...
# 5583                                                NaN  ...
# 5584                                                NaN  ...
# 5585                                                NaN  ...
#
#      MC9 MC10 Unnamed: 0_y merge_id  \
# 0                        0   272458
# 1                       17   272457
# 2                       38   272456
# 3                      269   272455
# 4                      449   271265
# ...   ..  ...          ...      ...
# 5581                  7263   200319
# 5582                  7269   200358
# 5583                  7296   200320
# 5584                  6846   200893
# 5585                  6878   200827
#
#                                                discours sexe
# 0     Monsieur le Député, Vous avez raison de pointe...    2
# 1     Bonjour Jean-Jacques BOURDIN.  J'ai plein de r...    2
# 2      Bonjour Caroline ROUX.  Je pense qu'il y a un...    2
# 3     M. le Ministre, Messieurs les Présidents, Mesd...    2
# 4     Nous sommes deux ans après le discours de lanc...    2
# ...                                                 ...  ...
# 5581   Bonjour Yves CALVI.  Non, je ne le crois pas ...    1
# 5582  En présence de Manuel VALLS Premier Ministre A...    1
# 5583  Messieurs les ministres, Mesdames, messieurs l...    1
# 5584  Mme la présidente. L'ordre du jour appelle le ...    2
# 5585  Monsieur le Commissaire Général à l'égalité de...    2
#
# [5586 rows x 25 columns]

# %%
DATA.to_csv('Sample_0_200.csv')
