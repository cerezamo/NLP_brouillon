# %%
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt
import numpy as np
from functools import reduce
from operator import add
from spacy.lang.fr.stop_words import STOP_WORDS as fr_stop
from nltk.corpus import stopwords
from collections import Counter
import spacy
from spacy.tokenizer import Tokenizer
import nltk
from nltk.tokenize import word_tokenize
from nltk import RegexpTokenizer
from os import path
#from PIL import Image
sent_detector = nltk.data.load('tokenizers/punkt/french.pickle')
nlp = spacy.load('fr_core_news_md') 
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# %% [markdown]
# ## Importations des données
#
# Nous importons un dataframe contenant uniquement 500 discours politiques ou déclaration. Les autres types d'élocutions n'ont pas été sélectionnées. Nous avons gardé du genre dans notre corpus de documents

# %%
df = pd.read_csv('minimal_df.csv')

# %% [markdown]
# Clean encodage

# %%
df.Texte = df.Texte.apply(lambda x : x.replace('\xa0','').replace('\x85','').replace('\x96','').replace('\x92',"'").replace('\x80',''))

# %%
len(df)
# Out:
# 500

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Id', 'Titre', 'Type', 'Theme', 'Prenom', 'Nom',
#        'Fonction', 'Date', 'Tags', 'Texte', 'Lien', 'sexe'],
#       dtype='object')

# %% [markdown]
# La variable que nous souhaitons classifier à l'aide des discours est le sexe. Dans un premier temps intéressons nous aux variables qui ne sont pas propres au texte.

# %%
df.sexe.map(str).value_counts()
# Out:
# 1    361
# 2    139
# Name: sexe, dtype: int64

# %%
len(df)
# Out:
# 500

# %%
labels = ['Masculin','Féminin']
colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99']
sizes = [ len(df[df.sexe ==1]),len(df[df.sexe ==2])]
fig, ax1 = plt.subplots()
plt.pie(sizes, colors = colors, labels=labels, autopct='%1.1f%%', startangle=90, pctdistance=0.85)
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
ax1.axis('equal')  
plt.tight_layout()
plt.title("Répartition du genre de l'auteur d'un discours ou d'une déclaration")
plt.show()

# %%
df['Annee']= df.Date.map(str).apply(lambda x:x[:4])

# %%
lst=[]
for an in df.Annee.unique():
    for s in df.sexe.unique():
        if s == 1:
            sexe= 'Masculin'
        else:
            sexe='Féminin'
        lst+=[(an,len(df[(df.Annee == an) & (df.sexe == s)]),sexe)]
data = pd.DataFrame(lst,columns=['Annee','Nb','Sexe'])
# Ou alors faut changer la et mettre elif sexe=2

# %%
plt.figure(figsize=(10,6))
sns.barplot(data = data,
            x='Annee',
            y='Nb',
           hue='Sexe')
plt.xticks(rotation = 45)
plt.title("Evolution du nombre d'élocutions par sexe de 1980 à aujourd'hui")
# Out:
# Text(0.5, 1.0, "Evolution du nombre d'élocutions par sexe de 1980 à aujourd'hui")

# %%
df.Tags.fillna('',inplace=True)
arr =df[df.sexe == 2].Tags.apply(lambda x: str(x).split(',')).array
arr = reduce(add,arr)
c = Counter(arr)
d_f = pd.DataFrame(c, index=['occurrences']).transpose().reset_index()
d_f.columns=['Themes', 'occurences']
d_f.occurences = d_f.occurences.apply(lambda x:(x/d_f.occurences.sum())*100)
d_f['sexe'] = 'Féminin'
arr =df[df.sexe == 1].Tags.apply(lambda x: str(x).split(',')).array
arr = reduce(add,arr)
c = Counter(arr)
d_m = pd.DataFrame(c, index=['occurrences']).transpose().reset_index()
d_m.columns=['Themes', 'occurences']
d_m.occurences = d_m.occurences.apply(lambda x:(x/d_m.occurences.sum())*100)
d_m['sexe'] = 'Masculin'
d = pd.concat([d_f,d_m])

# %%
plt.figure(figsize=(13,13))
plt.subplot(221)
sns.barplot(data = d[(d.occurences >= 0.5) & (d.Themes.apply(len) >0) & (d.sexe == 'Masculin')].sort_values('occurences',ascending=False).head(15),
            y='Themes',
            x='occurences',
           hue='sexe')
plt.title("Tags des élocutions des hommes")
plt.subplot(222)
sns.barplot(data = d[(d.occurences >= 0.6) & (d.Themes.apply(len) >0) & (d.sexe == 'Féminin')].sort_values('occurences',ascending=False).head(15),
            y='Themes',
            x='occurences',
           hue='sexe',
           color = 'red')
plt.title("Tags des élocutions des femmes")
plt.subplot(212)
sns.barplot(data = d[(d.occurences >= 2) & (d.Themes.apply(len) >0)].sort_values('occurences',ascending=False),
            y='Themes',
            x='occurences',
           hue='sexe')
plt.title("Tags des élocutions des deux sexes")
plt.subplots_adjust(wspace = 1.5)

# La aussi faudrait le faire en pourcentage du total 
# C'est fait, il faut juste corriger le troisieme graph

# %%
# THEMES
df.Theme.fillna('',inplace=True)
arr =df[df.sexe == 2].Theme.apply(lambda x: str(x).split(',')).array
arr = reduce(add,arr)
c = Counter(arr)
d_f = pd.DataFrame(c, index=['occurrences']).transpose().reset_index()
d_f.columns=['Themes', 'occurences']
d_f.occurences = d_f.occurences.apply(lambda x:(x/d_f.occurences.sum())*100)
d_f['sexe'] = 'Féminin'
arr =df[df.sexe == 1].Theme.apply(lambda x: str(x).split(',')).array
arr = reduce(add,arr)
c = Counter(arr)
d_m = pd.DataFrame(c, index=['occurrences']).transpose().reset_index()
d_m.columns=['Themes', 'occurences']
d_m.occurences = d_m.occurences.apply(lambda x:(x/d_m.occurences.sum())*100)
d_m['sexe'] = 'Masculin'
d = pd.concat([d_f,d_m])

# %%
plt.figure(figsize=(10,6))
sns.barplot(data = d[d.Themes != ''],hue = 'sexe',x='Themes',y='occurences')
plt.title('Répartition des thèmes des élocutions en fonction du sexe')
plt.xticks(rotation=0)
plt.show()

# %%
# FONCTIONS JAI PAS FAIT GAFFE MON SCRAPPER BUG ENCORE SUR LES FONCTIONS

# %% [markdown]
# Désormais nous allons nous concentrer sur le texte uniquement. Pour le faire, nous créeons dans un premier temps un ensemble de fonctions permettant d'étudier le texte.

# %% [markdown]
# Nous tokenizons notre text pour pouvoir le travailler et sortir d'autres variables par la suite.
# Nous allons tester plusieurs tokenizer pour voir lequel marche le mieux.
#
# Commençons par le tokenizer français de Spacy.

# %%
tokenizer = Tokenizer(nlp.vocab)

# %%
print(len([w for w in tokenizer(df.Texte[0])]))
# Out:
# 4259

# %% [markdown]
# Puis par le tokenizer de nltk

# %%
print(len(word_tokenize(df.Texte[0], language='french')))
# Out:
# 4673

# %% [markdown]
# Tokenizer basé sur le regex, on remarqu'il ne fonctionne pas bien car tokenize "c'est" en deux "c'" et "est".

# %%
toknizer = RegexpTokenizer(r'''\w'|\w+|[^\w\s]''')
len(toknizer.tokenize(df.Texte[0]))
# Out:
# 5177

# %% [markdown]
# On remarque une différence, le tokenizer de nltk tokenize la ponctuation tandis que celui de spacy ne le fait pas visiblement. On va donc utiliser plutôt le tokenizer de nltk.
#
# Pour les stopwords, il semblerait que la liste de spacy soit bien plus complète

# %%
len(list(fr_stop)),len(stopwords.words('french'))
# Out:
# (600, 157)

# %%
df['NbToken'] = df.Texte.apply(lambda x : len(word_tokenize(x,language='french')))
df['Token'] = df.Texte.apply(lambda x : word_tokenize(x,language='french'))

# %%
def cleanToken(x):
    """
        Fonction permettant de nettoyer et de tokenizer un texte
    """
    import string
    pct = string.punctuation+'...'+'\x92'+'«'+'»'+'``'+"''"+'``'
    x = x.replace('\xa0','').replace('\x85','').replace('\x96','')
    x = "".join(filter(lambda y: not y.isdigit(), x))
    sw = list(fr_stop)
    tokens = [str(w).lower() for w in word_tokenize(x, language='french')]
    tokens = [w for w in tokens if w not in pct]
    tokens = [w for w in tokens if w not in sw]
    return tokens
def count_punct(tokens):
    """
        Permet de compter la ponctuation
    """
    import string
    pct = string.punctuation +'...'+'\x92'+'«'+'»'+'``'
    cpt = 0
    for x in tokens:
        if x in pct:
            cpt+=1
    return cpt
def count_stopwords(tokens):
    """
        compte le nombre de stopwords à l'aide de spacy à partir de tokens
    """
    sw = list(fr_stop)
    return len([word for word in tokens if word.lower() in sw])
def Hapaxlegomena(tokens):
    """
        Compte le nombre de mot unique
    """
    s = pd.DataFrame(Counter(tokens).items(),columns=['Mot','nb'])
    return len(s[s.nb ==1])
def Hapaxdislegomena(tokens):
    """
        Compte le nombre de mot présent deux fois seulement
    """
    s = pd.DataFrame(Counter(tokens).items(),columns=['Mot','nb'])
    return len(s[s.nb ==2])
def extractPos(x):
    """
        Extrait le POS de chaque texte. A voir s'il y a un moyen de pas avoir à taper toutes les variables à la main
    """
    doc = nlp(x)
    lst_pos = [token.pos_ for token in doc]
    c = Counter(lst_pos)
    return [c['NOUN'],c['DET'],c['PUNCT'],c['ADJ'],c['ADP'],c['PRON'],c['VERB'],c['CCONJ'],c['NUM'],c['PROPN'],c['ADV'],c['SCONJ'],c['AUX'],c['INTJ']]

def nbArt(x):
    """
        Nombre d'article dans un document
    """
    doc = nlp(x)
    lst_pos = [token.tag_ for token in doc if token.tag_.split('|')[-1] == 'PronType=Art']
    return len(lst_pos)
def f_mesure(NbToken,nbnom,nbadj,nbprep,nbart,nbpro,nbverb,nbadv,nbint):
    """
        Inspiré par Heylighen and Dewaele, 2002
        Définit ici : https://www.cs.uic.edu/~liub/publications/EMNLP-2010-blog-gender.pdf comme étant
        F = 0.5 * [(freq.nom + freq.adjectif + freq.preposition + freq.article) - (freq.pronom + freq.verbe + freq.adverbe +
        freq.interjection) +100]
    """
    nbnom,nbadj,nbprep,nbart,nbpro,nbverb,nbadv,nbint = nbnom/NbToken,nbadj/NbToken,nbprep/NbToken,nbart/NbToken,nbpro/NbToken,nbverb/NbToken,nbadv/NbToken,nbint/NbToken
    nbnom,nbadj,nbprep,nbart,nbpro,nbverb,nbadv,nbint = nbnom*100,nbadj*100,nbprep*100,nbart*100,nbpro*100,nbverb*100,nbadv*100,nbint*100
    return 0.5*((nbnom + nbadj + nbprep + nbart)-(nbpro + nbverb + nbadv + nbint)+100)
def print_nine_dist(lst,df):
    """
        Input : 
            lst : liste de variables à print
            df : dataframe contenant ces valeurs
        Output : 
            Jusqu'à 9 displot des variables (3*3)
    """
    plt.figure(figsize=(10,14))
    for j in range(1,10):
        if len(lst)>j-1:
            var = lst[j-1]
        else:
            break
        q99= df[var].quantile(0.99)
        plt.subplot(330+j)
        sns.distplot(df[df.sexe == 2][var],color = 'red')
        sns.distplot(df[df.sexe == 1][var])
        plt.xlim(left=-0.1,right=q99)
    plt.subplots_adjust(wspace = 1)
    plt.show()
def NbSyllables(x):
    """
        Input : document
        Output : nbVoyelles
    """
    voyelles= 'aeiouy'
    return len([word for word in x if word.lower() in voyelles])
def flesh_reading_ease(ASL,ASW):
    """
        Score de lisibilité du texte : Plus il est élévé plus il est facile à comprendre
        FRE  = 206.835 - (1.015 × ASL) - (84.6 × ASW)
        ASL = NbToken/NbPhrases
        ASW = NbSyllables/NbToken
    """
    return 206.835 - (1.015 * ASL) - (84.6 * ASW)
def sent_detector_mano(x):
    """
        Détection de phrase à la main.
        Input : document
        Output : liste de phrases
        Problème avec les phrases finissant par : entrainant souvent une liste. 
        De même avec ;. Tentative réalisé
        
    """
    lst =[]
    phrase = []
    i = 0
    for caractere in x: 
        if not (caractere == ' ' and len(phrase) == 0) :
            phrase.append(caractere)
        if caractere in '?!.:;':
            if caractere == ':':
                if x[i+1].isupper() or x[i+2].isupper() or x[i+1] == '-' or x[i+2] == '-':
                    lst.append(''.join(phrase))
                    phrase = []
            elif caractere == ';':
                if x[i+1].isupper() or x[i+2].isupper() or x[i+1] == '-' or x[i+2] == '-':
                    lst.append(''.join(phrase))
                    phrase = []
            elif phrase != '.' or phrase != '?' or phrase != '!':
                lst.append(''.join(phrase))
                phrase = []
        i+=1
    return lst
def extraire_nb_mot(x):
    """
        Input : Document
        Output : nombre de mot
    """
    import string
    pct = string.punctuation+'...'+'\x92'+'«'+'»'+'``'+"''"+'``'
    x = x.replace('\xa0','').replace('\x85','').replace('\x96','')
    x = "".join(filter(lambda y: not y.isdigit(), x))
    tokens = [str(w).lower() for w in word_tokenize(x, language='french')]
    tokens = [w for w in tokens if w not in pct]
    return len(tokens)
def remove_source(x):
    x =  x[:x.find('Source:')]
    return x[:x.find('Source http')]

# %% [markdown]
# Il y a un problème avec le détecteur de phrase de nltk... J'ai du en coder un à la main qui à l'air de fonctionner mieux mais c'est pas non plus sur.

# %%
print(len(sent_detector.tokenize(df.Texte[1])))
#sent_detector.tokenize(df.Texte[1])
# Out:
# 46

# %%
print(len(df.Texte[1].split('.')))
#df.Texte[1].split('.'))
# Out:
# 77

# %%
print(len(sent_detector_mano(df.Texte[1])))
#sent_detector_mano(df.Texte[1])
# Out:
# 80

# %%
df.Texte = df.Texte.apply(remove_source)

# %%
df['NbCleanToken'] = df.Texte.apply(lambda x : len(cleanToken(x)))
df['NbSyllables'] = df.Texte.apply(NbSyllables)
df['NbMot'] = df.Texte.apply(extraire_nb_mot)
#Pb avec le FRE qui donne des négatifs, marche peut être pas en francais... 
df['NbPhrases'] = df.Texte.apply(lambda x:len(sent_detector_mano(x)))
df['FRE'] = df.apply(lambda row : flesh_reading_ease(row.NbMot/row.NbPhrases,row.NbSyllables/row.NbMot),axis=1)
df['CleanToken'] = df.Texte.apply(cleanToken)
df['NbCleanToken']=df.CleanToken.apply(len)
df['NbPonct'] = df.Texte.apply(count_punct)
df['NbSw'] = df.Token.apply(count_stopwords)
df['Hapaxlegomena']=df.CleanToken.apply(Hapaxlegomena)
df['Hapaxdislegomena']= df.CleanToken.apply(Hapaxdislegomena)
df['UniqueWordTx']= df.CleanToken.apply(lambda x:len(set(x))/len(x))
df['RateCleanRaw'] = df.NbCleanToken/df.NbToken
df['NbNom'],df['NbDet'],df['NbPunct'],df['NbAdj'],df['NbAdp'],df['NbPron'],df['NbVerb'],df['NbCconj'],df['NbNum'],df['NbPropn'],df['NbAdv'],df['NbSCONJ'],df['NbAUX'],df['NbIntj']=zip(*df.Texte.apply(extractPos))
df['NbArt']= df.Texte.apply(nbArt)
df['F_mesure'] = df.apply(lambda row: f_mesure(row.NbToken,row.NbNom,row.NbAdj,row.NbAdp,row.NbArt,row.NbPron,row.NbVerb,row.NbAdv,row.NbIntj),axis=1)

#C'est extrêmement long ... j'imagine même pas avec 20 000 discours ...
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-aac303037dc1> in <module>
#       5 df['NbPhrases'] = df.Texte.apply(lambda x:len(sent_detector_mano(x)))
#       6 df['FRE'] = df.apply(lambda row : flesh_reading_ease(row.NbMot/row.NbPhrases,row.NbSyllables/row.NbMot),axis=1)
# ----> 7 df['CleanToken'] = df.Texte.apply(cleanToken)
#       8 df['NbCleanToken']=df.CleanToken.apply(len)
#       9 df['NbPonct'] = df.Texte.apply(count_punct)
#
# ~\Anaconda3\envs\CNN\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3846             else:
#    3847                 values = self.astype(object).values
# -> 3848                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3849
#    3850         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# ...

# %%
df['Phrases'] = df.Texte.apply(sent_detector_mano)

# %%
lst = [ 'NbSyllables','NbPhrases','FRE','NbMot','NbToken','NbCleanToken', 'NbPonct', 'NbSw','Hapaxlegomena', 'Hapaxdislegomena', 
       'UniqueWordTx', 'RateCleanRaw','NbNom', 'NbDet', 'NbPunct', 'NbAdj', 'NbAdp', 'NbPron', 'NbVerb',
        'NbCconj', 'NbNum', 'NbPropn', 'NbAdv', 'NbSCONJ', 'NbAUX', 'NbIntj','NbArt', 'F_mesure'
        ] # 'NbCarac'
print(len(lst))
# Out:
# 28

# %%
df[['NbNom_prec']]=df[['NbNom']].div(df.NbMot,axis=0)

df[['NbDet_prec']]=df[['NbDet']].div(df.NbMot,axis=0)

df[['NbAdj_prec']]=df[['NbAdj']].div(df.NbMot,axis=0)

df[['NbPron_prec','NbVerb_perc','NbAUX_perc']]=df[['NbPron','NbVerb','NbAUX']].div(df.NbMot,axis=0)

# %% [markdown]
# Ci dessous, il est possible d'observer des différences entre les hommes et les femmes.

# %%
for i in range(0,18,9):
    print_nine_dist(lst[i:i+9],df)

# %%
print_nine_dist(lst[18:26],df)

# %%
lst = lst + ['NbNom_prec','NbDet_prec','NbAdj_prec',
    'NbPron_prec','NbVerb_perc',,'NbAUX_perc']
#Check quand on divise par le nombre de mots pas de diffà part sur les noms et pronoms

# %%
print_nine_dist(lst[28:34],df)

# %% [markdown]
# Au dela du nombre ce qui est interessant d'observer c'est quel type de pronom, nom, verbes les hommes et les femmes utilisent.

# %%
def Textlower(x):
    """
        Fonction permettant de nettoyer et de tokenizer un texte
    """
    x = x.replace('\xa0','').replace('\x85','').replace('\x96','')
    x= x.lower()
    x = "".join(filter(lambda y: not y.isdigit(), x))    
    return x

# %%
df['Textlower']=  df.Texte.apply(Textlower)

# %%
# Je moi 
def Pron_Type(x):
    """
        Fonction pourrie mais si tu arrives à faire mieux fait !! :D Je sais que tu aimes pas les boucles
    """
    sing1=[]
    doc = nlp(x)  
    for token in doc:
        attributes = ' '.join(' '.join(token.tag_.split('|')).split('__'))
        if 'PRON' in attributes:
            if 'Number=Sing' in attributes:
                if 'Person=1' in attributes:
                    sing1.append(token)
    return len(sing1)

# %%
 # Je moi 
def Pron_Type_Plur(x):
    """
        
    """
    plu1=[]
    plu2=[]
    plu3=[]
    doc = nlp(x)  
    for token in doc:
        attributes = ' '.join(' '.join(token.tag_.split('|')).split('__'))
        if 'PRON' in attributes:
            if 'Number=Plur' in attributes:
                if 'Person=1' in attributes:
                    plu1.append(token)
    return len(plu1)

# %%
df['PronJe']=df.Textlower.apply(Pron_Type)

# %%
df['PronNous']=df.Textlower.apply(Pron_Type_Plur)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-137-f7b5dab8bc07> in <module>
# ----> 1 df['PronNous']=df.Textlower.apply(Pron_Type_Plur)
#
# ~\Anaconda3\envs\CNN\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3846             else:
#    3847                 values = self.astype(object).values
# -> 3848                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3849
#    3850         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-135-e469f923757d> in Pron_Type_Plur(x)
#       7    plu2=[]
#       8    plu3=[]
# ----> 9    doc = nlp(x)
#      10    for token in doc:
#      11        attributes = ' '.join(' '.join(token.tag_.split('|')).split('__'))
#
# ...

# %%
df[['PronJe_perc','PronNous_perc']]=df[['PronJe','PronNous']].div(df.NbPron,axis=0)

# %%
lst = lst + ['PronJe_perc','PronNous_perc']

# %%
plt.figure(figsize=(14,14))
plt.subplot(2, 2, 1)
sns.distplot(df[df.sexe == 2]['PronJe_perc'],color = 'red')
sns.distplot(df[df.sexe == 1]['PronJe_perc'])
plt.subplot(2, 2, 2)
sns.distplot(df[df.sexe == 2]['PronNous_perc'],color = 'red')
sns.distplot(df[df.sexe == 1]['PronNous_perc'])
plt.show()
# On voit mieux faut agrandir un peu les graphs au dessus met en que deux par colonnes

# %% [markdown]
# De plus grosses différences sur le j en terme de distr mais une queue de distribution plus importante pour les nous en bas ( à voir finalement si je divise par le nombre de pronom pas vraiment.
# Trop hate d evoir les résultats sur le corpus entier !!
# Les distplot ca a pas trop de sens la comme c'est super biaisé a gauche ca suit une expo ou une gamma, on peut l'approximer par un expo si c'est faisble

# %%
import collections
doc = nlp(df.Textlower[1])
lst_pos = [token.pos_ for token in doc]
lst_word = [token for token in doc]
pronlist = [str(token) for token in doc if token.pos_ in ['PRON']]
pron_freq = sorted(set(zip(pronlist,[pronlist.count(w) for w in pronlist])), key = lambda x: x[1],reverse=True)

# %%
nlp = spacy.load('en_core_web_sm') 
doc=nlp("I'm so cool")
token = doc[1]
nlp.vocab.morphology.tag_map[token.tag_]
#la ca marche pk pas avec l'autre ca me gave il est ou ? C'est chiant de devoir split du texte
# Out:
# {74: 100, 'Tense_pres': True, 'VerbForm_fin': True}

# %% [markdown]
# Même délire avec les verbes voir les temps les plus utilisés !

# %%
# Je moi 
def Verb_Tens(x):
    """
        Fonction qui calcule le nombre de verbes selon le temps utilisé  
    """
    present=[]
    passe=[]
    futur=[]
    imp=[]
    doc = nlp(x)  
    for token in doc:
        attributes = ' '.join(' '.join(token.tag_.split('|')).split('__'))
        if 'AUX' in attributes:
            if 'Tense=Pres' in attributes:
                present.append(token)
            if 'Tense=Imp' in attributes:
                imp.append(token)
            if 'Tense=Fut' in attributes:
                futur.append(token)
            if 'Tense=Past' in attributes:
                passe.append(token)
        elif 'VERB' in attributes:
            if 'Tense=Pres' in attributes:
                present.append(token)
            if 'Tense=Imp' in attributes:
                imp.append(token)
            if 'Tense=Fut' in attributes:
                futur.append(token)
            if 'Tense=Past' in attributes:
                passe.append(token)
    return len(present), len(passe), len(futur), len(imp)

# %%
attrib=[]
for token in nlp(df.Texte[0]):
    attributes = ' '.join(' '.join(token.tag_.split('|')).split('__'))
    attrib.append(attributes)

# %%
nlp = spacy.load('en_core_web_sm') 
doc=nlp("I'm so cool")
token = doc[1]
nlp.vocab.morphology.tag_map[token.tag_]
# Out:
# {74: 100, 'Tense_pres': True, 'VerbForm_fin': True}

# %%
df['NbPres'],df['NbPast'],df['NbFut'],df['NbImp']  = zip(*df.Texte.apply(Verb_Tens))

# %%
df[['NbPres_perc','NbPast_perc','NbFut_perc','NbImp_perc']]=df[['NbPres','NbPast','NbFut','NbImp']].div(df.NbMots,axis=0)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-53-82b2154c67a2> in <module>
# ----> 1 df[['NbPres_perc','NbPast_perc','NbFut_perc','NbImp_perc']]=df[['NbPres','NbPast','NbFut','NbImp']].div(df.NbMots,axis=0)
#
# ~\Anaconda3\envs\CNN\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'NbMots'

# %%
plt.figure(figsize=(14,14))
plt.subplot(2, 2, 1)
sns.distplot(df[df.sexe == 2]['NbPres_perc'],color = 'red')
sns.distplot(df[df.sexe == 1]['NbPres_perc'])
plt.subplot(2, 2, 2)
sns.distplot(df[df.sexe == 2]['NbPast_perc'],color = 'red')
sns.distplot(df[df.sexe == 1]['NbPast_perc'])
plt.subplot(2, 2, 3)
sns.distplot(df[df.sexe == 2]['NbFut_perc'],color = 'red')
sns.distplot(df[df.sexe == 1]['NbFut_perc'])
plt.subplot(2, 2, 4)
sns.distplot(df[df.sexe == 2]['NbImp_perc'],color = 'red')
sns.distplot(df[df.sexe == 1]['NbImp_perc'])
plt.show()

# %% [markdown]
# L'imparfait ? Mais effet de taille aussi vu le peu de verbes qu'on retrouve
# Mettre peut être la moyenne aussi sur le graphique pour voir la diff même si ca va pas être fou.

# %% [markdown]
# Pour la ponctuation. Nombre de question, exclamations ?

# %%
# Je moi 
def Quest(x):
    """
        Fonction qui calcule le type de ponctuation  ?
    """
    doc = nlp(x) 
    quest = [w for w in doc if str(w) in ['?']]
    return len(quest)

# %%
# Je moi 
def Excl(x):
    """
        Fonction qui calcule le type de ponctuation  ! 
    """
    doc = nlp(x) 
    excl = [w for w in doc if str(w) in ['!']]
    return len(excl)

# %%
df['NbQuest']= df.Texte.apply(Quest)
df['NbExcl']= df.Texte.apply(Excl)

# %%
df[['NbQuest_perc','NbExcl_perc']]=df[['NbQuest','NbExcl']].div(df.NbToken,axis=0)

# %%
plt.figure(figsize=(14,14))
plt.subplot(2, 2, 1)
sns.distplot(df[df.sexe == 2]['NbQuest_perc'],color = 'red')
sns.distplot(df[df.sexe == 1]['NbQuest_perc'])
plt.subplot(2, 2, 2)
sns.distplot(df[df.sexe == 2]['NbExcl_perc'],color = 'red')
sns.distplot(df[df.sexe == 1]['NbExcl_perc'])
plt.show()

# %%
woman = np.array(Image.open("femme2.png"))
wc = WordCloud(background_color="white", max_words=100, mask=woman,
               stopwords=list(fr_stop)+["c'est","d'un","d'une","qu'il","n'est","j'ai","qu'elle"], contour_width=0.5, contour_color='black')
arr = reduce(add,df[df.sexe == 2].CleanToken.array)
corpus_f = ' '.join(arr)
wc.generate(corpus_f)
man = np.array(Image.open("homme.png"))
wc2 = WordCloud(background_color="white", max_words=100, mask=man,
               stopwords=list(fr_stop)+["c'est","d'un","d'une","qu'il","n'est","j'ai","qu'elle"], contour_width=1, contour_color='black')
arr = reduce(add,df[df.sexe == 1].CleanToken.array)
corpus_m = ' '.join(arr)
wc2.generate(corpus_m)

plt.figure(figsize=[10,10])
plt.subplot(121)
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
plt.subplot(122)
plt.imshow(wc2, interpolation='bilinear')
plt.axis("off")

plt.show()

#Je veux pas faire la féministe mais ces dessins ? hahaha

# %% [markdown]
# Ici ce serait plus intéressant avec uniquement des noms même si ca rend déjà hyper bien
# PS. Ces mots anglais ca vient d'où ?

# %% [markdown]
# # Reste à faire sur la première partie :
# - J'aimerais voir aussi les ponctuations, nombre de questions par exemple.
# - J'aimerais faire un graph avec les adjectifs les plus utilisés dans chaque groupe (positifs / négatifs)
# - Revoir les fonctions (secrétaire, ministre...)
# - Terminer la partie sur les sentiments (décider ce qu'on utilise)
# - Mettre les graphiques en forme et construire une analyse succinte de la première partie
# - checker les remarques diverses de toi et moi un peu dans le notebook
# - lancer tout ca sur les 15 000 déclarations ! faudra peut être utiliser le cluster de l'ENSAE, faudra parraléliser un minimum au moins les fonctions en boucle
# - Après c'est bon on peut se consacrer à la classification :D
# - Essayons de parraléliser un peu pour que ca tourne un peu plus vite quand on passera au niveau sup ?
# - Aussi peut être faire passer une seule fonction qui va nous chercher toute l'info d'un coup ca éviterai de faire la recherche sur tout le texte à chaque fois

# %% [markdown]
# ### Tentative de d'extraction des sentiments
#
# Premier test d'une méthode basé sur le lexicon FEEL(French Expanded Emotion Lexicon) qui est une traduction du NRC.
# http://advanse.lirmm.fr/feel.php
#
# Il faut avant cela lemmatizer nos mots.

# %%
feel = pd.read_csv('feel.csv',sep=';')
feel.set_index('id',inplace=True)
feel.sample(10)
# Out:
#                 word  polarity  joy  fear  sadness  anger  surprise  disgust
# id
# 3714         classer  positive    0     0        0      0         0        0
# 4627      de qualité  positive    0     0        0      0         0        0
# 7584      illégalité  negative    0     1        0      1         0        1
# 5073          diable  negative    0     1        1      1         0        1
# 10382         pigeon  negative    0     1        0      0         0        1
# 7778   inconséquence  negative    0     0        1      0         0        0
# 12473     sénescence  negative    0     0        1      0         0        0
# 4889        dépêcher  positive    0     0        0      0         0        0
# 8435          lasser  negative    0     0        1      0         0        0
# 2880        blaireau  negative    0     1        0      1         0        0

# %%
def cleanTokenLemme(x):
    """
        Fonction permettant de nettoyer et de tokenizer un texte tout en le lemmatizant
    """
    import string
    pct = string.punctuation+'...'+'\x92'+'«'+'»'+'``'+"''"+'``'
    x = [word.lemma_ for word in nlp(x)]
    x = ' '.join(x)
    x =str(x)
    x = x.replace('\xa0','').replace('\x85','').replace('\x96','')
    x = "".join(filter(lambda y: not y.isdigit(), x))
    sw = list(fr_stop)
    tokens = [str(w).lower() for w in word_tokenize(x, language='french')]
    tokens = [w for w in tokens if w not in pct]
    tokens = [w for w in tokens if w not in sw]
    tokens = [w for w in tokens if not len(w) <=2]
    return tokens
def check_polarity(tokens):
    """
        Analyse de sentiment de chaque mots
        Input : Tokens
        Output :  (%positive,%negative,%non trouvé) en fréquen
    """
    pos = feel[feel.polarity == 'positive'].word.values
    neg = feel[feel.polarity == 'negative'].word.values
    nb_pos = [word for word in tokens if word in pos]
    nb_neg = [word for word in tokens if word in neg]
    return [len(nb_pos)/len(tokens),len(nb_neg)/len(tokens),1 - (len(nb_pos) + len(nb_neg))/len(tokens)]
def extraction_emotion(tokens):
    """
        Permet d'extraire le nombre de mot classé dans 6 émotions différentes.
        Input : Tokens
        Output : (Joie,peur,tristesse,colère,surprise,dégoût) en fréquence
    """
    joie = [w for w in tokens if w in feel[feel.joy == 1].word.values]
    peur = [w for w in tokens if w in feel[feel.fear == 1].word.values]
    tristesse = [w for w in tokens if w in feel[feel.sadness == 1].word.values]
    colere = [w for w in tokens if w in feel[feel.anger == 1].word.values]
    surprise = [w for w in tokens if w in feel[feel.surprise == 1].word.values]
    degout = [w for w in tokens if w in feel[feel.disgust == 1].word.values]
    return [len(joie)/len(tokens),len(peur)/len(tokens),len(tristesse)/len(tokens),len(colere)/len(tokens),len(surprise)/len(tokens),len(degout)/len(tokens)]

# %%
extraction_emotion(cleanTokenLemme(df.Texte[0]))
# Out:
# [0.01434308663224326,
#  0.058519793459552494,
#  0.055077452667814115,
#  0.052782558806655194,
#  0.03442340791738382,
#  0.04475043029259897]

# %%
check_polarity(cleanTokenLemme(df.Texte[0]))
# Out:
# [0.4865174985656913, 0.07687894434882386, 0.4366035570854848]

# %%
df['CleanTokensLemme'] = df.Texte.apply(cleanTokenLemme)

# %%
df['PolPos'],df['PolNeg'],df['PolUnk'] = zip(*df.CleanTokensLemme.apply(check_polarity))
df['FreqJoie'],df['FreqPeur'],df['FreqSad'],df['FreqColere'],df['FreqSurprise'],df['FreqDegout'] = zip(*df.CleanTokensLemme.apply(extraction_emotion))

# %% [markdown]
# Mo : Et alors ca donne quoi ces freéquences ? :) Sympa la distinction de tous les sentiments.

# %%
plt.figure(figsize=(14,14))
plt.subplot(2, 2, 1)
sns.distplot(df[df.sexe == 2]['FreqJoie'],color = 'red')
sns.distplot(df[df.sexe == 1]['FreqJoie'])
plt.subplot(2, 2, 2)
sns.distplot(df[df.sexe == 2]['FreqPeur'],color = 'red')
sns.distplot(df[df.sexe == 1]['FreqPeur'])
plt.subplot(2, 2, 3)
sns.distplot(df[df.sexe == 2]['FreqSad'],color = 'red')
sns.distplot(df[df.sexe == 1]['FreqSad'])
plt.subplot(2, 2, 4)
sns.distplot(df[df.sexe == 2]['FreqColere'],color = 'red')
sns.distplot(df[df.sexe == 1]['FreqColere'])
plt.show()

# %% [markdown]
# Petit test avec textblob. Textblob c'est par phrase
#
# On ne prend la polarité qui varie entre [-1;1] avec -1 négatif et +1 positif. Le pb c'est comment transformer ça en score par la suite... ? Nb de phrase positive/négatif, sum de sentiment?
#
# Ok j'ai vu que toi tu faisais nombre de phrases au dela d'un certain seuil. Faut que je l'intègre
# Yes on peut faire ca par exemple :) mais si c'est pas top ne nous embetons pas.

# %%
from textblob import TextBlob
from textblob_fr import PatternTagger, PatternAnalyzer
for sentence in df['Phrases'][1][:5]:
    blob = TextBlob(sentence, pos_tagger=PatternTagger(), analyzer=PatternAnalyzer())
    print(sentence)
    print(blob.sentiment[0])
# Out:
# Je suis très heureux de vous retrouver pour cette 13ème édition du Festival de la fiction TV de La Rochelle.
# 1.0
# En 13 ans, Quentin RASPAIL et ses équipes ont su faire de ce rendez-vous une scène d'exposition, de rencontre avec le public, mais également un forum de réflexion professionnelle, comme l'atteste l'organisation des Ateliers de la Fiction et le Grand Débat qui se sont tenus hier.
# 0.13999999999999999
# Je tiens à les en féliciter chaleureusement.
# 0.0
# C'est aussi pour moi l'occasion de vous exposer les priorités de ma politique audiovisuelle et de faire un point sur les chantiers en cours : la relance de la fiction, le financement de la création  notamment en confortant les ressources et les ambitions de l'audiovisuel public - à l'heure où convergent les écrans, et où le Paysage audiovisuel français connaît une reconfiguration profonde, qui ne vous aura pas échappée.
# 0.115
# ...

# %%
df.columns
X = df[['NbToken', 'NbCleanToken', 'NbPhrases', 'NbMot', 'NbSw', 'Hapaxlegomena', 'Hapaxdislegomena',
       'UniqueWordTx', 'RateCleanRaw', 'NbNom', 'NbDet', 'NbPunct', 'NbAdj',
       'NbAdp', 'NbPron', 'NbVerb', 'NbCconj', 'NbNum', 'NbPropn', 'NbAdv',
       'NbSCONJ', 'NbAUX', 'NbIntj', 'NbArt', 'F_mesure', 'PolPos', 'PolNeg', 'PolUnk', 'FreqJoie',
       'FreqPeur', 'FreqSad', 'FreqColere', 'FreqSurprise', 'FreqDegout']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-57-0282e680c9fe> in <module>
#       4        'NbAdp', 'NbPron', 'NbVerb', 'NbCconj', 'NbNum', 'NbPropn', 'NbAdv',
#       5        'NbSCONJ', 'NbAUX', 'NbIntj', 'NbArt', 'F_mesure', 'PolPos', 'PolNeg', 'PolUnk', 'FreqJoie',
# ----> 6        'FreqPeur', 'FreqSad', 'FreqColere', 'FreqSurprise', 'FreqDegout']]
#
# ~\Anaconda3\envs\NLP\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# ~\Anaconda3\envs\NLP\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1550
# ...

# %% [markdown]
# Petit test de représentation sous forme d'un Kmean pour voir si on peut séparer les données

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=2, random_state=42, n_init=20, max_iter=1000, verbose=0).fit(X)

# %%
clusters = kmeans.predict(X)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-58-0552e05dcfa0> in <module>
# ----> 1 clusters = kmeans.predict(X)
#
# NameError: name 'kmeans' is not defined

# %%
for i in range(10):
    print(clusters[i], df['sexe'][i])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-59-f4b6a13f57ae> in <module>
#       1 for i in range(10):
# ----> 2     print(clusters[i], df['sexe'][i])
#
# NameError: name 'clusters' is not defined

# %%
from sklearn.manifold import TSNE
tsne = TSNE(n_components=2, verbose=1, perplexity=30, learning_rate=100.0, early_exaggeration=2., n_iter=250)
X_tsne = tsne.fit_transform(X)
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 500 samples in 0.004s...
# [t-SNE] Computed neighbors for 500 samples in 0.046s...
# [t-SNE] Computed conditional probabilities for sample 500 / 500
# [t-SNE] Mean sigma: 61.313340
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 2.444045
# [t-SNE] KL divergence after 251 iterations: .000000

# %%
import plotly.express as px
import plotly.graph_objects as go
import numpy as np


mapColors = {0:'lightseagreen', 1:'blueviolet'}
mapSentColors = {1:'lightseagreen', 2:'blueviolet'}
colorsClusters = [mapColors[c] for c in clusters]
colorsSentiment = [mapSentColors[s] for s in df.sexe]

fig = go.Figure(data=go.Scatter(
    x = X_tsne[:, 0],
    y = X_tsne[:, 1],
    hovertext = list(zip(df.Tags.apply(lambda x : x.split(',')), df.sexe)),
    mode='markers+text',
    marker=dict(
        size=4,
        color=colorsClusters, # colorsClusters or colorsSentiment
        colorscale='Viridis',
        showscale=True,
    )
))
fig.show()
# Out:
# <div>
#
#
#             <div id="25924c26-68e3-42fd-b061-8aa95ddcf96f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("25924c26-68e3-42fd-b061-8aa95ddcf96f")) {
#                     Plotly.newPlot(
#                         '25924c26-68e3-42fd-b061-8aa95ddcf96f',
# ...

# %% [markdown]
# Je ne sais pas trop quoi en déduire... A part que ça m'a l'air vraiment naze
#
# ## Passons désormais au n-grams
#
# Utilisation des tokens cleané et lemmatizer pour obtenir le n-gram
# Il est possible de voir que le bi-gram ne semble par très pertinant au regard des mots qui ressortent et qui semble ne pas trop varier en fonction du sexe.
#
# Mo : Faudrait peut être même faire ca avant ?

# %%
from nltk import ngrams
arr = df[df.sexe == 1].CleanTokensLemme.array
arr = reduce(add,arr)
arr = ' '.join(arr)
arr = arr.split()
bigram_count = Counter(ngrams(arr, 2))

# %%
bigram_count.most_common(50)
# Out:
# [(('madame', 'monsieur'), 508),
#  (('monsieur', 'président'), 374),
#  (('union', 'européen'), 306),
#  (('président', 'république'), 303),
#  (('projet', 'loi'), 253),
#  (('service', 'public'), 208),
#  (('monsieur', 'ministre'), 201),
#  (('million', 'euro'), 197),
#  (('mettre', 'place'), 188),
#  (('milliard', 'euro'), 165),
#  (('collectivité', 'local'), 152),
#  (('pouvoir', 'faire'), 150),
#  (('devoir', 'faire'), 124),
#  (('faire', 'sorte'), 109),
#  (('mise', 'place'), 108),
#  (('assemblée', 'national'), 107),
#  (('monsieur', 'député'), 106),
#  (('mise', 'oeuvre'), 105),
#  (('mettre', 'oeuvre'), 105),
#  (('conseil', 'européen'), 103),
#  (('collectivité', 'territorial'), 96),
#  (('économique', 'social'), 93),
#  (('savoir', 'faire'), 91),
#  (('affaire', 'étranger'), 87),
#  (('faire', 'face'), 85),
#  (('fin', 'année'), 83),
#  (('fonction', 'public'), 83),
#  (('faire', 'objet'), 80),
#  (('point', 'vue'), 78),
#  (('prendre', 'compte'), 77),
# ...

# %%
arr = df[df.sexe == 2].CleanTokensLemme.array
arr = reduce(add,arr)
arr = ' '.join(arr)
arr = arr.split()
bigram_count = Counter(ngrams(arr, 2))

# %%
bigram_count.most_common(50)
# Out:
# [(('madame', 'monsieur'), 177),
#  (('mettre', 'place'), 116),
#  (('monsieur', 'président'), 101),
#  (('secrétaire', 'état'), 92),
#  (('président', 'république'), 90),
#  (('prise', 'charge'), 87),
#  (('projet', 'loi'), 76),
#  (('développement', 'durable'), 73),
#  (('sécurité', 'social'), 63),
#  (('union', 'européen'), 58),
#  (('prendre', 'compte'), 57),
#  (('nouvelle', 'calédonie'), 55),
#  (('million', 'euro'), 54),
#  (('mettre', 'oeuvre'), 51),
#  (('mise', 'place'), 50),
#  (('service', 'public'), 48),
#  (('président', 'parole'), 46),
#  (('mise', 'oeuvre'), 45),
#  (('savoir', 'faire'), 41),
#  (('monsieur', 'secrétaire'), 41),
#  (('monsieur', 'député'), 40),
#  (('femme', 'homme'), 40),
#  (('plan', 'action'), 39),
#  (('faire', 'objet'), 36),
#  (('groupe', 'travail'), 36),
#  (('monsieur', 'sénateur'), 35),
#  (('enseignement', 'supérieur'), 33),
#  (('elizabeth', 'martichoux'), 33),
#  (('monsieur', 'ministre'), 32),
#  (('stratégie', 'national'), 32),
# ...

# %% [markdown]
# Passons aux tri-grams, on remarque déjà la présence toujours de personnes politiques (certains textes sont topés discours ou déclarations mais sont en réalité des interviews). Ensuite, on a énormément de (madame, monsieur + un titre), on supprime?
#
# Mo : Pour l'analyse des features comme on le fait la oui on va enlever. Pour les N-grams il faudrait que trier avant et ne prend que les types de mots qui ne sont pas de sprénoms.

# %%
arr = df[df.sexe == 1].CleanTokensLemme.array
arr = reduce(add,arr)
arr = ' '.join(arr)
arr = arr.split()
trigram_count = Counter(ngrams(arr, 3))

# %%
trigram_count.most_common(50)
# Out:
# [(('président', 'madame', 'monsieur'), 69),
#  (('monsieur', 'président', 'madame'), 65),
#  (('madame', 'monsieur', 'député'), 60),
#  (('président', 'parole', 'monsieur'), 44),
#  (('ministre', 'affaire', 'étranger'), 38),
#  (('jean', 'yves', 'drian'), 35),
#  (('projet', 'loi', 'finance'), 34),
#  (('monsieur', 'ministre', 'monsieur'), 33),
#  (('yves', 'drian', 'ministre'), 33),
#  (('madame', 'monsieur', 'ami'), 32),
#  (('madame', 'monsieur', 'sénateur'), 31),
#  (('madame', 'monsieur', 'élu'), 30),
#  (('madame', 'monsieur', 'parlementaire'), 29),
#  (('monsieur', 'président', 'conseil'), 27),
#  (('monsieur', 'ministre', 'madame'), 26),
#  (('ministre', 'madame', 'monsieur'), 26),
#  (('président', 'conseil', 'général'), 25),
#  (('savoir', 'pouvoir', 'compter'), 25),
#  (('monsieur', 'président', 'parole'), 24),
#  (('monsieur', 'président', 'monsieur'), 23),
#  (('enseignement', 'supérieur', 'recherche'), 23),
#  (('ministre', 'europe', 'affaire'), 23),
# ...

# %%
arr = df[df.sexe == 2].CleanTokensLemme.array
arr = reduce(add,arr)
arr = ' '.join(arr)
arr = arr.split()
trigram_count = Counter(ngrams(arr, 3))

# %%
trigram_count.most_common(50)
# Out:
# [(('monsieur', 'secrétaire', 'état'), 36),
#  (('delphine', 'gény', 'stephann'), 27),
#  (('gény', 'stephann', 'secrétaire'), 27),
#  (('stephann', 'secrétaire', 'état'), 27),
#  (('mme', 'delphine', 'gény'), 26),
#  (('monsieur', 'président', 'monsieur'), 25),
#  (('mme', 'secrétaire', 'état'), 25),
#  (('président', 'parole', 'mme'), 24),
#  (('ministre', 'économie', 'finance'), 24),
#  (('parole', 'mme', 'secrétaire'), 22),
#  (('secrétaire', 'état', 'auprès'), 22),
#  (('état', 'auprès', 'ministre'), 22),
#  (('auprès', 'ministre', 'économie'), 22),
#  (('pierre', 'yves', 'collombat'), 22),
#  (('président', 'parole', 'monsieur'), 22),
#  (('secrétaire', 'état', 'mme'), 20),
#  (('état', 'mme', 'delphine'), 20),
#  (('monsieur', 'président', 'madame'), 16),
#  (('président', 'madame', 'monsieur'), 16),
#  (('économie', 'finance', 'monsieur'), 16),
#  (('enseignement', 'supérieur', 'recherche'), 15),
#  (('mieux', 'prendre', 'compte'), 15),
# ...

# %% [markdown]
# Suppression de madame monsieur, c'est un peu mieux mais on a toujours des noms de personnes ce qui est plus du bruit qu'autre chose. Ensuite on a l'occurence de ces tri-grams qui n'est pas très élévés. Mais par contre on peut déjà voir que les femmes parles d'autres chose que les hommes

# %%
arr = df[df.sexe == 2].CleanTokensLemme.array
arr = reduce(add,arr)
arr = [w for w in arr if w not in ['madame','monsieur','mme']]
arr = ' '.join(arr)
arr = arr.split()
trigram_count = Counter(ngrams(arr, 3))
#La du coup enlever le premier paragraphe de salutation en entier

# %%
trigram_count.most_common(50)
# Out:
# [(('delphine', 'gény', 'stephann'), 27),
#  (('gény', 'stephann', 'secrétaire'), 27),
#  (('stephann', 'secrétaire', 'état'), 27),
#  (('ministre', 'économie', 'finance'), 24),
#  (('parole', 'secrétaire', 'état'), 22),
#  (('secrétaire', 'état', 'auprès'), 22),
#  (('état', 'auprès', 'ministre'), 22),
#  (('auprès', 'ministre', 'économie'), 22),
#  (('pierre', 'yves', 'collombat'), 22),
#  (('président', 'parole', 'secrétaire'), 21),
#  (('secrétaire', 'état', 'delphine'), 20),
#  (('état', 'delphine', 'gény'), 20),
#  (('enseignement', 'supérieur', 'recherche'), 15),
#  (('mieux', 'prendre', 'compte'), 15),
#  (('applaudissement', 'travée', 'groupe'), 15),
#  (('économie', 'finance', 'sénateur'), 15),
#  (('najat', 'vallaud', 'belkacem'), 14),
#  (('vallaud', 'belkacem', 'ministre'), 14),
#  (('égalité', 'femme', 'homme'), 12),
#  (('ici', 'fin', 'année'), 11),
#  (('aide', 'public', 'développemer'), 11),
#  (('groupe', 'socialiste', 'républicain'), 10),
# ...

# %%
arr = df[df.sexe == 1].CleanTokensLemme.array
arr = reduce(add,arr)
arr = [w for w in arr if w not in ['madame','monsieur']]
arr = ' '.join(arr)
arr = arr.split()
trigram_count = Counter(ngrams(arr, 3))

# %%
trigram_count.most_common(50)
# Out:
# [(('ministre', 'affaire', 'étranger'), 38),
#  (('jean', 'yves', 'drian'), 35),
#  (('projet', 'loi', 'finance'), 34),
#  (('yves', 'drian', 'ministre'), 33),
#  (('président', 'conseil', 'général'), 25),
#  (('savoir', 'pouvoir', 'compter'), 25),
#  (('enseignement', 'supérieur', 'recherche'), 23),
#  (('ministre', 'europe', 'affaire'), 23),
#  (('europe', 'affaire', 'étranger'), 23),
#  (('modèle', 'économique', 'social'), 22),
#  (('drian', 'ministre', 'europe'), 22),
#  (('technologie', 'information', 'communication'), 21),
#  (('président', 'parole', 'ministre'), 21),
#  (('ici', 'fin', 'année'), 20),
#  (('chef', 'etat', 'gouvernement'), 20),
#  (('projet', 'loi', 'relatif'), 20),
#  (('ministre', 'jean', 'yves'), 20),
#  (('banque', 'central', 'européen'), 19),
#  (('etat', 'collectivité', 'local'), 18),
#  (('loi', 'programmation', 'militaire'), 18),
#  (('parole', 'ministre', 'jean'), 18),
#  (('aide', 'public', 'développemer'), 17),
# ...

# %% [markdown]
# ### Test d'un TF-IDF avec bi-gram et n-gram

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
df['PhraseClean'] = df.CleanTokensLemme.apply(lambda x: ' '.join(x))

# %%
vectorizer_bi = TfidfVectorizer(ngram_range = (2,2),max_features = 1000)
vectorizer_tri = TfidfVectorizer(ngram_range = (3,3),max_features = 1000)

# %%
X_bi = vectorizer_bi.fit_transform(df.PhraseClean)
X_tri = vectorizer_tri.fit_transform(df.PhraseClean)

# %%
tsne = TSNE(n_components=2, verbose=1, perplexity=30, learning_rate=100.0, early_exaggeration=2., n_iter=250)
X_tsne = tsne.fit_transform(X_bi.toarray())
mapColors = {0:'lightseagreen', 1:'blueviolet'}
mapSentColors = {1:'lightseagreen', 2:'blueviolet'}
colorsClusters = [mapColors[c] for c in clusters]
colorsSentiment = [mapSentColors[s] for s in df.sexe]

fig = go.Figure(data=go.Scatter(
    x = X_tsne[:, 0],
    y = X_tsne[:, 1],
    hovertext = list(zip(df.Theme.apply(lambda x : x.split(',')), df.sexe)),
    mode='markers+text',
    marker=dict(
        size=4,
        color=colorsClusters, # colorsClusters or colorsSentiment
        colorscale='Viridis',
        showscale=True,
    )
))
fig.show()
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 500 samples in 0.028s...
# [t-SNE] Computed neighbors for 500 samples in 1.036s...
# [t-SNE] Computed conditional probabilities for sample 500 / 500
# [t-SNE] Mean sigma: 0.442969
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 10.913998
# [t-SNE] KL divergence after 251 iterations: .000000
# <div>
#
#
#             <div id="61adf647-f38a-40e4-94c6-c0562f69738e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
# ...

# %%
tsne = TSNE(n_components=2, verbose=1, perplexity=30, learning_rate=100.0, early_exaggeration=2., n_iter=250)
X_tsne = tsne.fit_transform(X_tri.toarray())
mapColors = {0:'lightseagreen', 1:'blueviolet'}
mapSentColors = {1:'lightseagreen', 2:'blueviolet'}
colorsClusters = [mapColors[c] for c in clusters]
colorsSentiment = [mapSentColors[s] for s in df.sexe]

fig = go.Figure(data=go.Scatter(
    x = X_tsne[:, 0],
    y = X_tsne[:, 1],
    hovertext = list(zip(df.Theme.apply(lambda x : x.split(',')), df.sexe)),
    mode='markers+text',
    marker=dict(
        size=4,
        color=colorsClusters, # colorsClusters or colorsSentiment
        colorscale='Viridis',
        showscale=True,
    )
))
fig.show()
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 500 samples in 0.050s...
# [t-SNE] Computed neighbors for 500 samples in 1.053s...
# [t-SNE] Computed conditional probabilities for sample 500 / 500
# [t-SNE] Mean sigma: 0.476044
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 6.347422
# [t-SNE] KL divergence after 251 iterations: .000000
# <div>
#
#
#             <div id="420b9359-016f-4ed2-b922-d16894633244" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
# ...

# %% [markdown]
# Au vu de ses résultats, je me dis qu'en non supervisé il identifie plus les themes et tags que le sexe.
#
# # Test de quelques classifieurs sur différentes méthodes

# %%
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression

# %%
def encode(x):
    if x == 1:
        return 0
    else:
        return 1
def predicteurs(model,X,y,rs = 42,split = 0.2,labels = ['Masculin','Féminin']):
    """
        Fonction permettant d'afficher la matrice de confusion et le f1 score pour un classifier donné
    """
    from sklearn.model_selection import train_test_split
    X_train,X_test,y_train,y_test= train_test_split(X,y,random_state = rs,test_size = split)
    model.fit(X_train,y_train)
    y_pred = model.predict(X_test)
    f1 = eval_predicteur(model,y_pred,y_test,labels)
    print('Sur {} personnes du test set , {} sont des femmes '.format(len(y_test),y_test.sum()))
    print('F1 score sur le test set {}'.format(f1))
def eval_predicteur(model,y_pred,y_true,labels):
    fontsize=14
    from sklearn.metrics import confusion_matrix
    from sklearn.metrics import f1_score
    cm = confusion_matrix(y_true,y_pred)
    df_cm = pd.DataFrame(
        cm, index=labels, columns=labels, 
    )
    plt.figure(figsize=(8,6))
    heatmap = sns.heatmap(df_cm, annot=True, fmt="d")
    heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
    heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
    plt.ylabel('Vrai label')
    plt.xlabel('Label prédits')
    plt.title('Matrice de confusion pour le model {}'.format(model))
    plt.show()
    return f1_score(y_true,y_pred)

# %%
models = [LinearSVC(verbose=1, random_state=42),RandomForestClassifier(n_estimators=300, max_depth=None, random_state=42, n_jobs=-1, verbose=1)]
for model in models:
    predicteurs(model,X_tri.toarray(),df.sexe.apply(encode))
# Out:
# [LibLinear]
# Sur 100 personnes du test set , 33 sont des femmes
# F1 score sur le test set 0.3076923076923077
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 192 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done 300 out of 300 | elapsed:    0.7s finished
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done 192 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done 300 out of 300 | elapsed:    0.0s finished
# Sur 100 personnes du test set , 33 sont des femmes
# F1 score sur le test set 0.054054054054054064

# %%
X = df[['NbToken', 'NbCleanToken', 'NbPhrases', 'NbMot', 'NbSw', 'Hapaxlegomena', 'Hapaxdislegomena',
       'UniqueWordTx', 'RateCleanRaw', 'NbNom', 'NbDet', 'NbPunct', 'NbAdj',
       'NbAdp', 'NbPron', 'NbVerb', 'NbCconj', 'NbNum', 'NbPropn', 'NbAdv',
       'NbSCONJ', 'NbAUX', 'NbIntj', 'NbArt', 'F_mesure', 'PolPos', 'PolNeg', 'PolUnk', 'FreqJoie',
       'FreqPeur', 'FreqSad', 'FreqColere', 'FreqSurprise', 'FreqDegout']]
models = [LinearSVC(random_state=42),
          RandomForestClassifier(n_estimators=300, max_depth=None, random_state=42, n_jobs=-1),
         GaussianNB(),LogisticRegression(random_state=42)]
for model in models:
    predicteurs(model,X,df.sexe.apply(encode))
# Out:
# C:\Users\franc\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\svm\base.py:929: ConvergenceWarning:
#
# Liblinear failed to converge, increase the number of iterations.
# Sur 100 personnes du test set , 33 sont des femmes
# F1 score sur le test set 0.46774193548387094
# Sur 100 personnes du test set , 33 sont des femmes
# F1 score sur le test set 0.1951219512195122
# Sur 100 personnes du test set , 33 sont des femmes
# F1 score sur le test set 0.5
# C:\Users\franc\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning:
#
# Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
# Sur 100 personnes du test set , 33 sont des femmes
# F1 score sur le test set 0.3829787234042553

# %%
from mlxtend.feature_selection import SequentialFeatureSelector as SFS
from mlxtend.plotting import plot_sequential_feature_selection as plot_sfs
sfs2 = SFS(GaussianNB(), 
          k_features='best', 
          forward=True,
          scoring='f1',
         n_jobs=-1,
         cv=10)
sfs2 = sfs2.fit(X,df.sexe.apply(encode))
fig = plot_sfs(sfs2.get_metric_dict(), kind='std_err')
plt.title('Sequential Backward Selection (w. StdErr)')
plt.grid()
plt.show()

# %% [markdown]
# Comme tu peux le voir, à partir de 10 variables on atteind un maximum qui n'est plus dépassé.
#
# Voici la liste des 10 features : 'Hapaxlegomena','RateCleanRaw','NbAdp','NbPron','NbPropn','NbIntj','PolPos','FreqJoie','FreqSad','FreqSurprise'
#
# Mo: Je vois oui, essayosn d'intégrer les nouvelles variables on sait jamais sinon on passe aux réseaux de neurones.
# La c'est décevant on fait pas mieux que l'aléatoire.. après on a peu de données et je pense qu'il faudra mieux nettoyer.
# Aprés on voit le biais du nombre de discours de chaque catégorie. Le modèle a la limite préfère dire 100 % hommes (pas dans tous mais c'est ce qui théoriquement devrait se passer)

# %%
sfs2.subsets_
# Out:
# {1: {'feature_idx': (18,),
#   'cv_scores': array([0.        , 0.        , 0.        , 0.        , 0.        ,
#          0.29411765, 0.        , 0.        , 0.        , 0.        ]),
#   'avg_score': 0.02941176470588235,
#   'feature_names': ('NbPropn',)},
#  2: {'feature_idx': (18, 22),
#   'cv_scores': array([0.        , 0.        , 0.        , 0.        , 0.        ,
#          0.48979592, 0.24242424, 0.        , 0.        , 0.        ]),
#   'avg_score': 0.07322201607915893,
#   'feature_names': ('NbPropn', 'NbIntj')},
#  3: {'feature_idx': (14, 18, 22),
#   'cv_scores': array([0.32      , 0.48888889, 0.50980392, 0.4       , 0.48979592,
#          0.45833333, 0.48979592, 0.375     , 0.39215686, 0.5       ]),
#   'avg_score': 0.44237748432706414,
#   'feature_names': ('NbPron', 'NbPropn', 'NbIntj')},
#  4: {'feature_idx': (8, 14, 18, 22),
#   'cv_scores': array([0.64705882, 0.42857143, 0.47826087, 0.42857143, 0.45      ,
# ...

# %% [markdown]
# # Réseaux de neurone - un premier test

# %% [markdown]
# - C'est extrêmement long, ici je ne fais qu'appliquer le TD4 à notre problème j'ai encore beaucoup de questions. J'ai d'abord tenté sur google colab pour pas avoir a tout installé et surtout il y a un GPU ce que j'ai pas.
# - J'ai tenté de fine tuné un peu mais faut que je me renseigne sur comment parce que c ame paraît ultra flou encore.
# - Il faudrait vectoriser avec les n-grams j'imagine aussi
# - Je pensais qu'il fallait rentrer des matrices avec des phrases séparées mais du coup ca sera pas le même taille en entrée ?

# %%
import torch 
import torch.nn as nn
import torch.nn.functional as F 
import pandas as pd
import spacy
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
import numpy as np
from spacy.lang.fr.stop_words import STOP_WORDS as fr_stop
from nltk.corpus import stopwords
from collections import Counter
from spacy.tokenizer import Tokenizer
nlp = spacy.load('fr_core_news_md')

# %%
# Je reprends le code du lab 4 qui utilise LSTM 
class SequenceLabeller(nn.Module):

    def __init__(self, embedding_dim, hidden_dim, vocab_size, num_classes, sequence_model="LSTM"):
        super(SequenceLabeller, self).__init__()

        self.hidden_dim = hidden_dim
        self.word_embeddings = nn.Embedding(vocab_size, embedding_dim)
        
        if sequence_model == "LSTM":
            # The LSTM takes word embeddings as inputs, and outputs hidden states
            # with dimensionality hidden_dim.
            self.seq = nn.LSTM(embedding_dim, hidden_dim,batch_first=True)
        else:
            raise(Exception("Sequence model {} not supported".format(sequence_model)))

        # The linear layer that maps from hidden state space to class space
        self.hidden2tag = nn.Linear(hidden_dim, num_classes)

    def forward(self, sentence):
        embeds = self.word_embeddings(sentence)
        seq_output, (h_n,c_n) = self.seq(embeds)
        tag_space = self.hidden2tag(seq_output)
        # Although we will be performing binary classification, this is a 
        # general implementation displaying what should be done for n_classes>2
        tag_scores = F.log_softmax(tag_space, dim=2) # Computationally efficient for the criterion
        return tag_scores

# %%
data=pd.read_csv('minimal_df.csv')

# %%
data=data[['Texte','sexe']]
data.sexe=data['sexe'].replace(2,0) #Femme 0

# %%
data=data.sample(frac=1).reset_index(drop=True)

# %%
nlp = spacy.load('fr_core_news_md')

# %%
# Je met en forme comme il l'a fait, la je ne sais pas on met en tensor tout le discours ( ici sent) ??? 
data_clean=[]
for i in range(len(data)):
    tokenized = nlp(data['Texte'][i])
    sent = [token.text for token in  tokenized]
    score = data['sexe'][i]
    data_clean.append((sent,int(score)))

# %%
training_data = data_clean[:int(len(data)*4/5)]
test_data = data_clean[int(len(data)*4/5):]

# %%
#On met en tensor 
def prepare_sequence(seq, to_ix):
    idxs = [to_ix[w] if w in to_ix else len(to_ix) for w in seq]
    idxs = torch.tensor(idxs, dtype=torch.long).unsqueeze(0)
    return idxs

# %%
word_to_ix = {}
tag_to_ix = {}
for sent, tag in training_data:
    if tag not in tag_to_ix:
        tag_to_ix[tag] = len(tag_to_ix)
    for word in sent:
        if word not in word_to_ix:
            word_to_ix[word] = len(word_to_ix)
print(tag_to_ix)
print(word_to_ix)
#D'accord on a bien deux labels  ( en inverse ? chelou) , normalement il y avait pas de manquants mais faudra faire une condition pour vérifier
# Attention descend à fond c'est hyper long mais du coup on voit comment il indexe. notamment on voit des trucs bizarres
#comme le texte est pas nettoyé en amont normal ...... faudra le faire mais je sais pas trop comment ce qu'on enlève ou pas
# Il faudra trouver une règle quand même pour enlever les trucs bizarres. 
#Aussi il existe des correcteurs d'orthographe qu'on devrait appliquer j'en vois bcp !
# Out:
# {1: 0, 0: 1}
# ...

# %%
# the additional vocabulary element is to account for unkown words
model = SequenceLabeller(50, 100, len(word_to_ix)+1, len(tag_to_ix)) 
inputs = prepare_sequence(training_data[0][0], word_to_ix)
with torch.no_grad():
    sent_scores = model(torch.cat([inputs]))
    print("Input tokens {} scores {} ".format(inputs, sent_scores))
    #Donc dans les tensor scores on a les proba si j'ai bien compris ??
# Out:
# Input tokens tensor([[  0,   1,   2,  ..., 542, 543, 544]]) scores tensor([[[-0.6521, -0.7359],
#          [-0.6322, -0.7580],
#          [-0.6478, -0.7407],
#          ...,
#          [-0.6554, -0.7324],
#          [-0.6630, -0.7242],
#          [-0.5854, -0.8140]]])

# %%
loss_function = nn.NLLLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.01) #learning rate ? Je ne sais pas vraiment faudra tester en fonction 
# des résultats et si il apprend trop ou pas assez

# %%
#C'est pas parralélisé ... faudra voir au prochain cours comment on fait. ATTENTION LOOONNNGGG
from torch.nn.functional import one_hot
n_epochs = 5 # Mon ordinateur ne tient pas vraiment plus, il faut que je relance quand il y a rien qui tourne dessus
for epoch in range(n_epochs): 
    loss_mean_ep = 0
    n_sample = 0
    for sentence, tags in training_data:
        if len(sentence) < 2: continue
        # On met tous les gradients à 0 
        model.zero_grad()
        # On transforme nos discours en tensors (des vecteurs interprétables par le modèle)
        sentence_in = prepare_sequence(sentence, word_to_ix)
        #import pdb
        #pdb.set_trace()
        targets = prepare_sequence([tags], tag_to_ix)
        one_hot_targets = one_hot(targets.squeeze(0), num_classes=len(tag_to_ix))
        # Le modèle est appliqué 
        tag_scores = model(sentence_in)
        # On calcule la loss et on met à jour les poids avec les gradients enregistrés
        #  Compute the loss, gradients, and update the parameters by
        #  calling optimizer.step()
        #import pdb
        #pdb.set_trace()
        # print(tag_scores.shape, one_hot_targets.shape)
        loss = loss_function(tag_scores, one_hot_targets)
        loss_mean_ep += loss
        n_sample += 1
        loss.backward()
        optimizer.step()
    print("Epoch {} loss {:0.4f} ".format(epoch, loss/n_sample))
    #  Du coup ca converge quand même :)
# Out:
# Epoch 0 loss 0.0013
# Epoch 1 loss 0.0010
# Epoch 2 loss 0.0008
# Epoch 3 loss 0.0007
# Epoch 4 loss 0.0007

# %% [markdown]
# Evaluation du modèle sur la test

# %%
with torch.no_grad():
    for sentence, tag in test_data:
        sentence_in = prepare_sequence(sentence, word_to_ix)
        sentence_tag = 'Positive' if tag==1 else 'Negative'
        tag_scores = model(sentence_in)
        positive_score = torch.mean(torch.exp(tag_scores.squeeze(0)[:, 1])).item()
        print("{} sentence scored {} \"{}\"."
              "".format(sentence_tag, positive_score,' '.join(sentence)) )
# Out:
# Positive sentence scored 0.4404216706752777 "Messieurs les ministres , Mesdames et messieurs , Permettez - moi de remercier chaleureusement M. Vu Khoan , ministre du commerce , pour son accueil , et de saluer M. Do Nhu Dihn qui va présider aujourd'hui à nos travaux . Messieurs , j' ai un plaisir tout particulier à ouvrir , en votre compagnie , cette journée de travail consacrée aux moyens de soutenir , d' appuyer et de dynamiser nos entreprises à l' étranger . Dans un environnement international chaque jour plus compétitif , cet appui que l' Etat peut apporter aux entreprises est infiniment précieux . C' est dire tout l' intérêt de ce séminaire que je conçois aussi comme un bel exemple de la coopération entre nos deux pays , comme un moment privilégié d' échanges et de travail en commun . Mais l' intérêt de ce séminaire tient évidemment à l' évolution ambitieuse du Vietnam et de sa participation de plus en plus active aux échanges internationaux . 1 . L' ouverture économique du Vietn
# ...

# %%
from sklearn.metrics import roc_auc_score, classification_report

ground_truth, scores = [], []
with torch.no_grad():
    for sentence, tag in test_data:
        sentence_in = prepare_sequence(sentence, word_to_ix)
        ground_truth.append(tag)
        tag_scores = model(sentence_in)
        scores.append(torch.mean(torch.exp(tag_scores.squeeze(0)[:, 1])).item())

print("The AUC is ", roc_auc_score(ground_truth, scores))
print("Classification report:\n", classification_report(ground_truth, 
                                                      np.array(scores)>0.5))
# Out:
# The AUC is  0.476930548810102
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.29      1.00      0.45        29
#            1       1.00      0.01      0.03        71
#
#     accuracy                           0.30       100
#    macro avg       0.65      0.51      0.24       100
# weighted avg       0.79      0.30      0.15       100

# %%
import seaborn as sns

def sentiment_heatmap(sentence):
    tokens = [str(w.text) for w in nlp(sentence)]
    sentence_in = prepare_sequence(tokens, word_to_ix)
    tag_scores = model(sentence_in)
    token_sentiments = torch.exp(tag_scores)[:, :, 1].detach().numpy()
    sns.heatmap(token_sentiments, xticklabels=tokens)
    plt.title("sentence score: "
              "{}".format(torch.mean(torch.exp(tag_scores)[:, :, 1]).item()))
    plt.show()

# %%
import matplotlib.pyplot as plt

sample_sentences =["Comme l'a montré le grand débat hier"] # Phrase que j'ai pris dans le premier discours au hasard 
 
for sentence in sample_sentences:
    sentiment_heatmap(sentence)

# %% [markdown]
# Ok difficile à interpréter ! En tout cas, en terme de performance on est largement en dessous de tes classifieurs !
